# %% [markdown]
# # Gensim

# %% [markdown]
# Author: **Tasnima Sadekova**

# %% [markdown]
# **Gensim** is billed as a Natural Language Processing package that does ‘Topic Modeling for Humans’. But it is practically much more than that. It is a leading and a state-of-the-art package for processing texts, working with *word vector models* and for building *topic models*.

# %% [markdown]
# But the width and scope of facilities to build and evaluate topic models are unparalleled in gensim, plus many more convenient facilities for text processing.
#
# Also, another significant advantage with gensim is: it lets you handle large text files without having to load the entire file in memory.

# %%
from gensim import corpora
import gensim.downloader as api
from gensim.utils import simple_preprocess
from gensim.models.word2vec import Word2Vec
from gensim.models.doc2vec import TaggedDocument, Doc2Vec

# %% [markdown]
# ## Dictionary and Corpus

# %% [markdown]
# **Dictionary** is an object that maps each word to a unique id.
#
# The dictionary object is typically used to create a ‘bag of words’ Corpus. It is this Dictionary and the bag-of-words (Corpus) that are used as inputs to topic modeling and other models that Gensim specializes in.

# %% [markdown]
# *gensim.utils.simple_preprocess* Convert a document into a list of lowercase tokens, ignoring tokens that are too short or too long.

# %%
# from a list of sentences

documents = ["If you use a car frequently, the first step to cutting",
             "down your emissions may well be to simply", 
             "fully consider the", 
             "alternatives available to you."
             ]

# Tokenize(split) the sentences into words
texts = [[text for text in doc.split()] for doc in documents]

# Create dictionary
dictionary = corpora.Dictionary(texts)

print(dictionary)
print(dictionary.token2id)
# Out:
# Dictionary(23 unique tokens: ['If', 'a', 'car', 'cutting', 'first']...)
# {'If': 0, 'a': 1, 'car': 2, 'cutting': 3, 'first': 4, 'frequently,': 5, 'step': 6, 'the': 7, 'to': 8, 'use': 9, 'you': 10, 'be': 11, 'down': 12, 'emissions': 13, 'may': 14, 'simply': 15, 'well': 16, 'your': 17, 'consider': 18, 'fully': 19, 'alternatives': 20, 'available': 21, 'you.': 22}

# %% [markdown]
# With simple_preprocess

# %%
dictionary = corpora.Dictionary(simple_preprocess(line, deacc=True) for line in documents)
print(dictionary)
print(dictionary.token2id)
# Out:
# Dictionary(21 unique tokens: ['car', 'cutting', 'first', 'frequently', 'if']...)
# {'car': 0, 'cutting': 1, 'first': 2, 'frequently': 3, 'if': 4, 'step': 5, 'the': 6, 'to': 7, 'use': 8, 'you': 9, 'be': 10, 'down': 11, 'emissions': 12, 'may': 13, 'simply': 14, 'well': 15, 'your': 16, 'consider': 17, 'fully': 18, 'alternatives': 19, 'available': 20}

# %%
#from document
dictionary = corpora.Dictionary(simple_preprocess(line, deacc=True) for line in open('sample.txt', encoding='utf-8'))

# %% [markdown]
# **Corpus** object that contains the word id and its frequency in each document.
#
# The dictionary object is typically used to create a ‘bag of words’ Corpus. It is this Dictionary and the bag-of-words (Corpus) that are used as inputs to topic modeling and other models that Gensim specializes in.

# %% [markdown]
# - Bag of words

# %%
my_docs = ["Who let the dogs out?",
           "Who? Who? Who? Who?"]

# Tokenize the docs
tokenized_list = [simple_preprocess(doc) for doc in my_docs]

# Create the Corpus
dictionary = corpora.Dictionary()

#allow_update=True - add new words to dictionary
bow_corpus = [dictionary.doc2bow(doc, allow_update=True) for doc in tokenized_list]
print(bow_corpus)

print("Dictionary: ", dictionary.token2id)
# Out:
# [[(0, 1), (1, 1), (2, 1), (3, 1), (4, 1)], [(4, 4)]]
# Dictionary:  {'dogs': 0, 'let': 1, 'out': 2, 'the': 3, 'who': 4}

# %% [markdown]
# The (0, 1) in line 1 means, the word with id=0 appears once in the 1st document.
# Likewise, the (4, 4) in the second list item means the word with id 4 appears 4 times in the second document. And so on.

# %% [markdown]
# - TfIdf

# %%
from gensim import models
import numpy as np

documents = ["This is the first line",
             "This is the second sentence",
             "This third document"]

# Create the Dictionary and Corpus
mydict = corpora.Dictionary([simple_preprocess(line) for line in documents])
corpus = [mydict.doc2bow(simple_preprocess(line)) for line in documents]

# Show the Word Weights in Corpus
for doc in corpus:
    print([[mydict[id], freq] for id, freq in doc])
print()

# Create the TF-IDF model
tfidf = models.TfidfModel(corpus, smartirs='ntc')

# Show the TF-IDF weights
for doc in tfidf[corpus]:
    print([[mydict[id], np.around(freq, decimals=2)] for id, freq in doc])
# Out:
# [['first', 1], ['is', 1], ['line', 1], ['the', 1], ['this', 1]]
# [['is', 1], ['the', 1], ['this', 1], ['second', 1], ['sentence', 1]]
# [['this', 1], ['document', 1], ['third', 1]]
#
# [['first', 0.63], ['is', 0.31], ['line', 0.63], ['the', 0.31], ['this', 0.13]]
# [['is', 0.31], ['the', 0.31], ['this', 0.13], ['second', 0.63], ['sentence', 0.63]]
# [['this', 0.15], ['document', 0.7], ['third', 0.7]]

# %% [markdown]
# Save and load

# %%
# Save the Dict and Corpus
dictionary.save('mydict.dict')  # save dict to disk
corpora.MmCorpus.serialize('bow_corpus.mm', bow_corpus)  # save corpus to disk

# %%
# Load them back
loaded_dict = corpora.Dictionary.load('mydict.dict')

corpus = corpora.MmCorpus('bow_corpus.mm')
for line in corpus:
    print(line)
# Out:
# [(0, 1.0), (1, 1.0), (2, 1.0), (3, 1.0), (4, 1.0)]
# [(4, 4.0)]

# %% [markdown]
# ## Datasets

# %% [markdown]
# Gensim provides an inbuilt API to download popular text datasets and word embedding models.
#
# A comprehensive list of available datasets and models is maintained [here](https://raw.githubusercontent.com/RaRe-Technologies/gensim-data/master/list.json).
#
# Using the API to download the dataset is as simple as calling the ```api.load()``` method with the right data or model name.

# %%
import gensim.downloader as api

# %% [markdown]
# Short description

# %%
api.info('text8')
api.info('glove-wiki-gigaword-50')
# Out:
# {'num_records': 400000,
#  'file_size': 69182535,
#  'base_dataset': 'Wikipedia 2014 + Gigaword 5 (6B tokens, uncased)',
#  'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/glove-wiki-gigaword-50/__init__.py',
#  'license': 'http://opendatacommons.org/licenses/pddl/',
#  'parameters': {'dimension': 50},
#  'description': 'Pre-trained vectors based on Wikipedia 2014 + Gigaword, 5.6B tokens, 400K vocab, uncased (https://nlp.stanford.edu/projects/glove/).',
#  'preprocessing': 'Converted to w2v format with `python -m gensim.scripts.glove2word2vec -i <fname> -o glove-wiki-gigaword-50.txt`.',
#  'read_more': ['https://nlp.stanford.edu/projects/glove/',
#   'https://nlp.stanford.edu/pubs/glove.pdf'],
#  'checksum': 'c289bc5d7f2f02c6dc9f2f9b67641813',
#  'file_name': 'glove-wiki-gigaword-50.gz',
#  'parts': 1}

# %% [markdown]
# Dataset

# %%
dataset = api.load("text8")
data = [d for d in dataset]
print(data[0])
# Out:
# [==================================================] 100.0% 31.6/31.6MB downloaded
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term', 'is', 'still', 'used', 'in', 'a', 'pejorative', 'way', 'to', 'describe', 'any', 'act', 'that', 'used', 'violent', 'means', 'to', 'destroy', 'the', 'organization', 'of', 'society', 'it', 'has', 'also', 'been', 'taken', 'up', 'as', 'a', 'positive', 'label', 'by', 'self', 'defined', 'anarchists', 'the', 'word', 'anarchism', 'is', 'derived', 'from', 'the', 'greek', 'without', 'archons', 'ruler', 'chief', 'king', 'anarchism', 'as', 'a', 'political', 'philosophy', 'is', 'the', 'belief', 'that', 'rulers', 'are', 'unnecessary', 'and', 'should', 'be', 'abolished', 'although', 'there', 'are', 'differing', 'interpretations', 'of', 'what', 'this', 'means', 'anarchism', 'also', 'refers', 'to', 'related', 'social', 'movements', 'that', 'advocate', 'the', 'elimination', 'of', 'authoritarian', 'institutions', 'particularly', 'the', 'state', 'the', 'word', 'anarchy', 'as', 'most', 'anarchists', 'use', 'it', 'does', 'not', 'imply', 'chaos', 'nihilism', 'or', 'anomie', 'but', 'rather', 'a', 'harmonious', 'anti', 'authoritarian', 'society', 'in', 'place', 'of', 'what', 'are', 'regarded', 'as', 'authoritarian', 'political', 'structures', 'and', 'coercive', 'economic', 'institutions', 'anarchists', 'advocate', 'social', 'relations', 'based', 'upon', 'voluntary', 'association', 'of', 'autonomous', 'individuals', 'mutual', 'aid', 'and', 'self', 'governance', 'while', 'anarchism', 'is', 'most', 'easily', 'defined', 'by', 'what', 'it', 'is', 'against', 'anarchists', 'also', 'offer', 'positive', 'visions', 'of', 'what', 'they', 'believe', 'to', 'be', 'a', 'truly', 'free', 'society', 'however', 'ideas', 'about', 'how', 'an', 'anarchist', 'society', 'might', 'work', 'vary', 'considerably', 'especially', 'with', 'respect', 'to', 'economics', 'there', 'is', 'also', 'disagreement', 'about', 'how', 'a', 'free', 'society', 'might', 'be', 'brought', 'about', 'origins', 'and', 'predecessors', 'kropotkin', 'and', 'others', 'argue', 'that', 'before', 'recorded', 'history', 'human', 'society', 'was', 'organized', 'on', 'anarchist', 'principles', 'most', 'anthropologists', 'follow', 'kropotkin', 'and', 'engels', 'in', 'believing', 'that', 'hunter', 'gatherer', 'bands', 'were', 'egalitarian', 'and', 'lacked', 'division', 'of', 'labour', 'accumulated', 'wealth', 'or', 'decreed', 'law', 'and', 'had', 'equal', 'access', 'to', 'resources', 'william', 'godwin', 'anarchists', 'including', 'the', 'the', 'anarchy', 'organisation', 'and', 'rothbard', 'find', 'anarchist', 'attitudes', 'in', 'taoism', 'from', 'ancient', 'china', 'kropotkin', 'found', 'similar', 'ideas', 'in', 'stoic', 'zeno', 'of', 'citium', 'according', 'to', 'kropotkin', 'zeno', 'repudiated', 'the', 'omnipotence', 'of', 'the', 'state', 'its', 'intervention', 'and', 'regimentation', 'and', 'proclaimed', 'the', 'sovereignty', 'of', 'the', 'moral', 'law', 'of', 'the', 'individual', 'the', 'anabaptists', 'of', 'one', 'six', 'th', 'century', 'europe', 'are', 'sometimes', 'considered', 'to', 'be', 'religious', 'forerunners', 'of', 'modern', 'anarchism', 'bertrand', 'russell', 'in', 'his', 'history', 'of', 'western', 'philosophy', 'writes', 'that', 'the', 'anabaptists', 'repudiated', 'all', 'law', 'since', 'they', 'held', 'that', 'the', 'good', 'man', 'will', 'be', 'guided', 'at', 'every', 'moment', 'by', 'the', 'holy', 'spirit', 'from', 'this', 'premise', 'they', 'arrive', 'at', 'communism', 'the', 'diggers', 'or', 'true', 'levellers', 'were', 'an', 'early', 'communistic', 'movement', 'during', 'the', 'time', 'of', 'the', 'english', 'civil', 'war', 'and', 'are', 'considered', 'by', 'some', 'as', 'forerunners', 'of', 'modern', 'anarchism', 'in', 'the', 'modern', 'era', 'the', 'first', 'to', 'use', 'the', 'term', 'to', 'mean', ...

# %% [markdown]
# Pretrained model

# %%
w2v_model = api.load("glove-wiki-gigaword-50")
w2v_model.most_similar('blue')
# Out:
# INFO - 09:47:56: loading projection weights from C:\Users\v00524754/gensim-data\glove-wiki-gigaword-50\glove-wiki-gigaword-50.gz
# INFO - 09:50:52: loaded (400000, 50) matrix from C:\Users\v00524754/gensim-data\glove-wiki-gigaword-50\glove-wiki-gigaword-50.gz
# INFO - 09:50:53: precomputing L2-norms of word weight vectors
# [('red', 0.8901656866073608),
#  ('black', 0.8648407459259033),
#  ('pink', 0.8452916741371155),
#  ('green', 0.8346816301345825),
#  ('yellow', 0.8320708274841309),
#  ('purple', 0.829311192035675),
#  ('white', 0.8225342035293579),
#  ('orange', 0.8114303350448608),
#  ('bright', 0.799933910369873),
#  ('colored', 0.787665605545044)]

# %% [markdown]
# ## Word2Vec

# %% [markdown]
# A word embedding model is a model that can provide numerical vectors for a given word. Using the Gensim’s downloader API, you can download pre-built word embedding models like word2vec, fasttext, GloVe and ConceptNet. These are built on large corpuses of commonly occurring text data such as wikipedia, google news etc.
#
# The training algorithms in the Gensim package were actually ported from the original Word2Vec implementation by Google and extended with additional functionality.
#
# This module implements the word2vec family of algorithms, using *highly optimized* C routines, data streaming and Pythonic interfaces.
#
# **Parameters:**
#
# - ```sentences``` - (iterable of iterables, optional) – The sentences iterable can be simply a *list of lists of tokens*, but for larger corpora, consider an *iterable* that streams the sentences directly from disk/network.
# - ```corpus_file``` (str, optional) – Path to a corpus file in LineSentence format. You may use this argument instead of sentences to get performance boost. *Only one of sentences or corpus_file arguments need to be passed*
# - ```size``` = 100 - Dimensionality of the word vectors.
# - ```window``` = 5 - Maximum distance between the current and predicted word within a sentence.
# - ```min_count``` = 5 (int, optional) – Ignores all words with total frequency lower than this.
# - ```workers``` = 3 (int, optional) – Use these many worker threads to train the model (=faster training with multicore machines).
# - ```sg``` = 0 ({0, 1}, optional) – Training algorithm: 1 for skip-gram; otherwise CBOW.
# - ```hs``` = 0 ({0, 1}, optional) – If 1, hierarchical softmax will be used for model training. If 0, and negative is non-zero, negative sampling will be used.
# - ```negative``` = 5 (int, optional) – If > 0, negative sampling will be used, the int for negative specifies how many “noise words” should be drawn (usually between 5-20). If set to 0, no negative sampling is used.
# - ```max_vocab_size``` = None (int, optional) Limits the RAM during vocabulary building; if there are more unique words than this, then prune the infrequent ones.
# - ```iter``` (int, optional) – Number of iterations (epochs) over the corpus.

# %%
import logging 
# Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)

# %%
dataset = api.load("text8")
data = [d for d in dataset]

# Train Word2Vec model
model = Word2Vec(data)
# Out:
# INFO - 09:35:39: collecting all words and their counts
# INFO - 09:35:39: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 09:36:01: collected 253854 word types from a corpus of 17005207 raw words and 1701 sentences
# INFO - 09:36:01: Loading a fresh vocabulary
# INFO - 09:36:03: effective_min_count=5 retains 71290 unique words (28% of original 253854, drops 182564)
# INFO - 09:36:03: effective_min_count=5 leaves 16718844 word corpus (98% of original 17005207, drops 286363)
# INFO - 09:36:05: deleting the raw counts dictionary of 253854 items
# INFO - 09:36:05: sample=0.001 downsamples 38 most-common words
# INFO - 09:36:05: downsampling leaves estimated 12506280 word corpus (74.8% of prior 16718844)
# INFO - 09:36:06: estimated required memory for 71290 words and 100 dimensions: 92677000 bytes
# INFO - 09:36:06: resetting layer weights
# INFO - 09:37:59: training model with 3 workers on 71290 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# INFO - 09:38:00: EPOCH 1 - PROGRESS: at 1.76% examples, 219530 words/s, in_qsize 6, out_qsize 0
# INFO - 09:38:01: EPOCH 1 - PROGRESS: at 3.59% examples, 221838 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:02: EPOCH 1 - PROGRESS: at 5.23% examples, 216010 words/s, in_qsize 3, out_qsize 0
# INFO - 09:38:03: EPOCH 1 - PROGRESS: at 6.47% examples, 198054 words/s, in_qsize 6, out_qsize 0
# INFO - 09:38:04: EPOCH 1 - PROGRESS: at 8.52% examples, 206254 words/s, in_qsize 6, out_qsize 0
# INFO - 09:38:05: EPOCH 1 - PROGRESS: at 10.35% examples, 209214 words/s, in_qsize 4, out_qsize 1
# INFO - 09:38:06: EPOCH 1 - PROGRESS: at 12.52% examples, 217455 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:07: EPOCH 1 - PROGRESS: at 14.52% examples, 221378 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:08: EPOCH 1 - PROGRESS: at 16.75% examples, 226263 words/s, in_qsize 6, out_qsize 0
# INFO - 09:38:09: EPOCH 1 - PROGRESS: at 18.40% examples, 224134 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:10: EPOCH 1 - PROGRESS: at 19.75% examples, 217803 words/s, in_qsize 6, out_qsize 2
# INFO - 09:38:11: EPOCH 1 - PROGRESS: at 21.75% examples, 220344 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:12: EPOCH 1 - PROGRESS: at 23.69% examples, 222194 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:13: EPOCH 1 - PROGRESS: at 25.40% examples, 221298 words/s, in_qsize 6, out_qsize 0
# INFO - 09:38:14: EPOCH 1 - PROGRESS: at 26.98% examples, 219619 words/s, in_qsize 6, out_qsize 0
# INFO - 09:38:15: EPOCH 1 - PROGRESS: at 28.87% examples, 220698 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:16: EPOCH 1 - PROGRESS: at 30.57% examples, 220188 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:17: EPOCH 1 - PROGRESS: at 32.16% examples, 218684 words/s, in_qsize 6, out_qsize 1
# INFO - 09:38:18: EPOCH 1 - PROGRESS: at 34.10% examples, 219337 words/s, in_qsize 6, out_qsize 1
# INFO - 09:38:20: EPOCH 1 - PROGRESS: at 35.98% examples, 220008 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:21: EPOCH 1 - PROGRESS: at 38.33% examples, 223123 words/s, in_qsize 6, out_qsize 1
# INFO - 09:38:22: EPOCH 1 - PROGRESS: at 40.51% examples, 225043 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:23: EPOCH 1 - PROGRESS: at 42.62% examples, 226430 words/s, in_qsize 6, out_qsize 0
# INFO - 09:38:24: EPOCH 1 - PROGRESS: at 44.33% examples, 225310 words/s, in_qsize 5, out_qsize 2
# INFO - 09:38:25: EPOCH 1 - PROGRESS: at 46.27% examples, 225944 words/s, in_qsize 6, out_qsize 1
# INFO - 09:38:26: EPOCH 1 - PROGRESS: at 48.32% examples, 226986 words/s, in_qsize 6, out_qsize 0
# INFO - 09:38:27: EPOCH 1 - PROGRESS: at 50.03% examples, 226235 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:28: EPOCH 1 - PROGRESS: at 51.73% examples, 225749 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:29: EPOCH 1 - PROGRESS: at 53.91% examples, 227344 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:30: EPOCH 1 - PROGRESS: at 56.03% examples, 228478 words/s, in_qsize 6, out_qsize 0
# INFO - 09:38:31: EPOCH 1 - PROGRESS: at 58.26% examples, 229810 words/s, in_qsize 6, out_qsize 1
# INFO - 09:38:32: EPOCH 1 - PROGRESS: at 60.20% examples, 229833 words/s, in_qsize 6, out_qsize 2
# INFO - 09:38:33: EPOCH 1 - PROGRESS: at 61.61% examples, 228121 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:34: EPOCH 1 - PROGRESS: at 63.08% examples, 226725 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:35: EPOCH 1 - PROGRESS: at 64.79% examples, 226249 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:36: EPOCH 1 - PROGRESS: at 66.67% examples, 226381 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:37: EPOCH 1 - PROGRESS: at 68.49% examples, 226398 words/s, in_qsize 6, out_qsize 0
# INFO - 09:38:38: EPOCH 1 - PROGRESS: at 70.25% examples, 226152 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:39: EPOCH 1 - PROGRESS: at 71.60% examples, 224732 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:40: EPOCH 1 - PROGRESS: at 73.31% examples, 224476 words/s, in_qsize 6, out_qsize 0
# INFO - 09:38:41: EPOCH 1 - PROGRESS: at 75.37% examples, 225046 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:42: EPOCH 1 - PROGRESS: at 77.72% examples, 226366 words/s, in_qsize 6, out_qsize 0
# INFO - 09:38:43: EPOCH 1 - PROGRESS: at 79.66% examples, 226633 words/s, in_qsize 6, out_qsize 0
# INFO - 09:38:44: EPOCH 1 - PROGRESS: at 81.13% examples, 225558 words/s, in_qsize 6, out_qsize 0
# INFO - 09:38:45: EPOCH 1 - PROGRESS: at 83.30% examples, 226553 words/s, in_qsize 6, out_qsize 0
# INFO - 09:38:46: EPOCH 1 - PROGRESS: at 85.48% examples, 227433 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:47: EPOCH 1 - PROGRESS: at 87.65% examples, 228258 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:48: EPOCH 1 - PROGRESS: at 89.95% examples, 229493 words/s, in_qsize 5, out_qsize 1
# INFO - 09:38:49: EPOCH 1 - PROGRESS: at 92.06% examples, 229810 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:50: EPOCH 1 - PROGRESS: at 94.12% examples, 230234 words/s, in_qsize 6, out_qsize 2
# INFO - 09:38:51: EPOCH 1 - PROGRESS: at 96.36% examples, 231133 words/s, in_qsize 6, out_qsize 0
# INFO - 09:38:52: EPOCH 1 - PROGRESS: at 98.65% examples, 231994 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:53: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:38:53: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:38:53: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:38:53: EPOCH - 1 : training on 17005207 raw words (12504866 effective words) took 53.8s, 232453 effective words/s
# INFO - 09:38:54: EPOCH 2 - PROGRESS: at 1.35% examples, 170195 words/s, in_qsize 6, out_qsize 1
# INFO - 09:38:55: EPOCH 2 - PROGRESS: at 3.00% examples, 176104 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:56: EPOCH 2 - PROGRESS: at 3.82% examples, 151684 words/s, in_qsize 5, out_qsize 0
# INFO - 09:38:57: EPOCH 2 - PROGRESS: at 5.76% examples, 171795 words/s, in_qsize 6, out_qsize 0
# INFO - 09:38:58: EPOCH 2 - PROGRESS: at 7.64% examples, 183057 words/s, in_qsize 6, out_qsize 0
# INFO - 09:38:59: EPOCH 2 - PROGRESS: at 9.82% examples, 196662 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:00: EPOCH 2 - PROGRESS: at 11.46% examples, 195677 words/s, in_qsize 6, out_qsize 0
# INFO - 09:39:01: EPOCH 2 - PROGRESS: at 13.11% examples, 196814 words/s, in_qsize 6, out_qsize 0
# INFO - 09:39:02: EPOCH 2 - PROGRESS: at 14.58% examples, 192830 words/s, in_qsize 6, out_qsize 0
# INFO - 09:39:03: EPOCH 2 - PROGRESS: at 16.23% examples, 193996 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:04: EPOCH 2 - PROGRESS: at 18.34% examples, 199176 words/s, in_qsize 4, out_qsize 1
# INFO - 09:39:05: EPOCH 2 - PROGRESS: at 20.16% examples, 201202 words/s, in_qsize 6, out_qsize 0
# INFO - 09:39:06: EPOCH 2 - PROGRESS: at 21.99% examples, 203094 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:07: EPOCH 2 - PROGRESS: at 23.75% examples, 204013 words/s, in_qsize 6, out_qsize 0
# INFO - 09:39:08: EPOCH 2 - PROGRESS: at 25.22% examples, 202429 words/s, in_qsize 6, out_qsize 0
# INFO - 09:39:09: EPOCH 2 - PROGRESS: at 26.75% examples, 201605 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:11: EPOCH 2 - PROGRESS: at 28.63% examples, 203180 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:12: EPOCH 2 - PROGRESS: at 30.34% examples, 203110 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:13: EPOCH 2 - PROGRESS: at 31.92% examples, 202935 words/s, in_qsize 6, out_qsize 0
# INFO - 09:39:14: EPOCH 2 - PROGRESS: at 33.22% examples, 200764 words/s, in_qsize 4, out_qsize 1
# INFO - 09:39:15: EPOCH 2 - PROGRESS: at 35.16% examples, 202352 words/s, in_qsize 4, out_qsize 1
# INFO - 09:39:16: EPOCH 2 - PROGRESS: at 37.57% examples, 206389 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:17: EPOCH 2 - PROGRESS: at 39.39% examples, 207184 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:18: EPOCH 2 - PROGRESS: at 41.45% examples, 209155 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:19: EPOCH 2 - PROGRESS: at 42.68% examples, 206984 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:20: EPOCH 2 - PROGRESS: at 44.50% examples, 207736 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:21: EPOCH 2 - PROGRESS: at 46.03% examples, 207106 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:22: EPOCH 2 - PROGRESS: at 47.62% examples, 206000 words/s, in_qsize 6, out_qsize 1
# INFO - 09:39:23: EPOCH 2 - PROGRESS: at 49.32% examples, 206166 words/s, in_qsize 6, out_qsize 1
# INFO - 09:39:24: EPOCH 2 - PROGRESS: at 51.26% examples, 207282 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:25: EPOCH 2 - PROGRESS: at 52.32% examples, 204555 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:26: EPOCH 2 - PROGRESS: at 54.38% examples, 205974 words/s, in_qsize 4, out_qsize 1
# INFO - 09:39:27: EPOCH 2 - PROGRESS: at 56.61% examples, 208080 words/s, in_qsize 6, out_qsize 0
# INFO - 09:39:28: EPOCH 2 - PROGRESS: at 58.38% examples, 208311 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:29: EPOCH 2 - PROGRESS: at 60.61% examples, 209780 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:30: EPOCH 2 - PROGRESS: at 62.14% examples, 209210 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:31: EPOCH 2 - PROGRESS: at 64.26% examples, 210494 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:32: EPOCH 2 - PROGRESS: at 66.37% examples, 211624 words/s, in_qsize 6, out_qsize 0
# INFO - 09:39:33: EPOCH 2 - PROGRESS: at 68.43% examples, 212654 words/s, in_qsize 6, out_qsize 0
# INFO - 09:39:34: EPOCH 2 - PROGRESS: at 70.43% examples, 213540 words/s, in_qsize 6, out_qsize 0
# INFO - 09:39:35: EPOCH 2 - PROGRESS: at 72.60% examples, 214925 words/s, in_qsize 6, out_qsize 0
# INFO - 09:39:36: EPOCH 2 - PROGRESS: at 73.84% examples, 213404 words/s, in_qsize 6, out_qsize 0
# INFO - 09:39:37: EPOCH 2 - PROGRESS: at 75.72% examples, 213549 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:38: EPOCH 2 - PROGRESS: at 77.95% examples, 214512 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:39: EPOCH 2 - PROGRESS: at 79.60% examples, 214287 words/s, in_qsize 3, out_qsize 2
# INFO - 09:39:40: EPOCH 2 - PROGRESS: at 81.78% examples, 215127 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:41: EPOCH 2 - PROGRESS: at 83.01% examples, 213767 words/s, in_qsize 6, out_qsize 1
# INFO - 09:39:43: EPOCH 2 - PROGRESS: at 84.77% examples, 213763 words/s, in_qsize 6, out_qsize 0
# INFO - 09:39:44: EPOCH 2 - PROGRESS: at 86.95% examples, 214590 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:45: EPOCH 2 - PROGRESS: at 88.71% examples, 214608 words/s, in_qsize 4, out_qsize 1
# INFO - 09:39:46: EPOCH 2 - PROGRESS: at 89.59% examples, 212521 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:47: EPOCH 2 - PROGRESS: at 90.48% examples, 210252 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:48: EPOCH 2 - PROGRESS: at 91.30% examples, 208249 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:49: EPOCH 2 - PROGRESS: at 92.95% examples, 208158 words/s, in_qsize 6, out_qsize 0
# INFO - 09:39:50: EPOCH 2 - PROGRESS: at 94.30% examples, 207345 words/s, in_qsize 4, out_qsize 1
# INFO - 09:39:51: EPOCH 2 - PROGRESS: at 96.12% examples, 207614 words/s, in_qsize 6, out_qsize 0
# INFO - 09:39:52: EPOCH 2 - PROGRESS: at 98.00% examples, 207861 words/s, in_qsize 6, out_qsize 0
# INFO - 09:39:53: EPOCH 2 - PROGRESS: at 99.47% examples, 207437 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:53: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:39:53: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:39:53: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:39:53: EPOCH - 2 : training on 17005207 raw words (12506328 effective words) took 60.3s, 207465 effective words/s
# INFO - 09:39:54: EPOCH 3 - PROGRESS: at 1.82% examples, 224859 words/s, in_qsize 6, out_qsize 0
# INFO - 09:39:55: EPOCH 3 - PROGRESS: at 4.06% examples, 248314 words/s, in_qsize 6, out_qsize 0
# INFO - 09:39:56: EPOCH 3 - PROGRESS: at 6.29% examples, 254386 words/s, in_qsize 6, out_qsize 1
# INFO - 09:39:57: EPOCH 3 - PROGRESS: at 8.41% examples, 254694 words/s, in_qsize 5, out_qsize 0
# INFO - 09:39:58: EPOCH 3 - PROGRESS: at 10.41% examples, 253005 words/s, in_qsize 6, out_qsize 0
# INFO - 09:39:59: EPOCH 3 - PROGRESS: at 12.35% examples, 250917 words/s, in_qsize 6, out_qsize 0
# INFO - 09:40:01: EPOCH 3 - PROGRESS: at 14.23% examples, 247273 words/s, in_qsize 4, out_qsize 1
# INFO - 09:40:02: EPOCH 3 - PROGRESS: at 16.52% examples, 251806 words/s, in_qsize 4, out_qsize 1
# INFO - 09:40:03: EPOCH 3 - PROGRESS: at 18.58% examples, 252209 words/s, in_qsize 6, out_qsize 0
# INFO - 09:40:04: EPOCH 3 - PROGRESS: at 20.63% examples, 252074 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:05: EPOCH 3 - PROGRESS: at 22.52% examples, 249445 words/s, in_qsize 6, out_qsize 0
# INFO - 09:40:06: EPOCH 3 - PROGRESS: at 24.40% examples, 248280 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:07: EPOCH 3 - PROGRESS: at 26.51% examples, 248938 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:08: EPOCH 3 - PROGRESS: at 28.34% examples, 247610 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:09: EPOCH 3 - PROGRESS: at 30.45% examples, 248876 words/s, in_qsize 6, out_qsize 0
# INFO - 09:40:10: EPOCH 3 - PROGRESS: at 32.33% examples, 246974 words/s, in_qsize 4, out_qsize 1
# INFO - 09:40:11: EPOCH 3 - PROGRESS: at 34.16% examples, 245860 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:12: EPOCH 3 - PROGRESS: at 36.68% examples, 249573 words/s, in_qsize 6, out_qsize 0
# INFO - 09:40:13: EPOCH 3 - PROGRESS: at 38.74% examples, 249922 words/s, in_qsize 6, out_qsize 0
# INFO - 09:40:14: EPOCH 3 - PROGRESS: at 41.09% examples, 251999 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:15: EPOCH 3 - PROGRESS: at 43.27% examples, 253023 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:16: EPOCH 3 - PROGRESS: at 45.15% examples, 251612 words/s, in_qsize 6, out_qsize 0
# INFO - 09:40:17: EPOCH 3 - PROGRESS: at 46.56% examples, 248009 words/s, in_qsize 6, out_qsize 0
# INFO - 09:40:18: EPOCH 3 - PROGRESS: at 48.38% examples, 246960 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:19: EPOCH 3 - PROGRESS: at 50.44% examples, 247082 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:20: EPOCH 3 - PROGRESS: at 51.68% examples, 243523 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:21: EPOCH 3 - PROGRESS: at 52.56% examples, 237586 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:22: EPOCH 3 - PROGRESS: at 53.26% examples, 232381 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:23: EPOCH 3 - PROGRESS: at 54.14% examples, 227874 words/s, in_qsize 4, out_qsize 1
# INFO - 09:40:24: EPOCH 3 - PROGRESS: at 55.32% examples, 224767 words/s, in_qsize 6, out_qsize 0
# INFO - 09:40:25: EPOCH 3 - PROGRESS: at 56.44% examples, 221925 words/s, in_qsize 6, out_qsize 0
# INFO - 09:40:26: EPOCH 3 - PROGRESS: at 57.38% examples, 218651 words/s, in_qsize 4, out_qsize 0
# INFO - 09:40:27: EPOCH 3 - PROGRESS: at 59.26% examples, 218886 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:28: EPOCH 3 - PROGRESS: at 60.73% examples, 217777 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:29: EPOCH 3 - PROGRESS: at 62.85% examples, 218954 words/s, in_qsize 6, out_qsize 0
# INFO - 09:40:30: EPOCH 3 - PROGRESS: at 65.43% examples, 221677 words/s, in_qsize 6, out_qsize 0
# INFO - 09:40:31: EPOCH 3 - PROGRESS: at 67.55% examples, 222498 words/s, in_qsize 6, out_qsize 1
# INFO - 09:40:32: EPOCH 3 - PROGRESS: at 69.84% examples, 224057 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:33: EPOCH 3 - PROGRESS: at 71.72% examples, 224338 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:34: EPOCH 3 - PROGRESS: at 73.66% examples, 224808 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:35: EPOCH 3 - PROGRESS: at 75.78% examples, 225496 words/s, in_qsize 6, out_qsize 2
# INFO - 09:40:36: EPOCH 3 - PROGRESS: at 77.84% examples, 225922 words/s, in_qsize 6, out_qsize 0
# INFO - 09:40:38: EPOCH 3 - PROGRESS: at 80.25% examples, 227411 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:39: EPOCH 3 - PROGRESS: at 82.07% examples, 227255 words/s, in_qsize 6, out_qsize 0
# INFO - 09:40:40: EPOCH 3 - PROGRESS: at 84.19% examples, 227852 words/s, in_qsize 6, out_qsize 0
# INFO - 09:40:41: EPOCH 3 - PROGRESS: at 86.54% examples, 229186 words/s, in_qsize 4, out_qsize 1
# INFO - 09:40:42: EPOCH 3 - PROGRESS: at 88.95% examples, 230578 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:43: EPOCH 3 - PROGRESS: at 91.01% examples, 231073 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:44: EPOCH 3 - PROGRESS: at 93.36% examples, 232098 words/s, in_qsize 4, out_qsize 1
# INFO - 09:40:45: EPOCH 3 - PROGRESS: at 95.06% examples, 231607 words/s, in_qsize 6, out_qsize 0
# INFO - 09:40:46: EPOCH 3 - PROGRESS: at 97.35% examples, 232529 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:47: EPOCH 3 - PROGRESS: at 99.29% examples, 232659 words/s, in_qsize 4, out_qsize 1
# INFO - 09:40:47: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:40:47: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:40:47: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:40:47: EPOCH - 3 : training on 17005207 raw words (12507592 effective words) took 53.7s, 233081 effective words/s
# INFO - 09:40:48: EPOCH 4 - PROGRESS: at 2.23% examples, 277081 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:49: EPOCH 4 - PROGRESS: at 4.47% examples, 273695 words/s, in_qsize 5, out_qsize 1
# INFO - 09:40:50: EPOCH 4 - PROGRESS: at 6.29% examples, 253771 words/s, in_qsize 4, out_qsize 1
# INFO - 09:40:51: EPOCH 4 - PROGRESS: at 8.47% examples, 255342 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:52: EPOCH 4 - PROGRESS: at 10.52% examples, 255334 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:53: EPOCH 4 - PROGRESS: at 12.93% examples, 262131 words/s, in_qsize 6, out_qsize 1
# INFO - 09:40:54: EPOCH 4 - PROGRESS: at 15.40% examples, 268036 words/s, in_qsize 6, out_qsize 0
# INFO - 09:40:55: EPOCH 4 - PROGRESS: at 17.70% examples, 269250 words/s, in_qsize 4, out_qsize 1
# INFO - 09:40:56: EPOCH 4 - PROGRESS: at 19.46% examples, 263808 words/s, in_qsize 6, out_qsize 0
# INFO - 09:40:57: EPOCH 4 - PROGRESS: at 21.58% examples, 263774 words/s, in_qsize 5, out_qsize 0
# INFO - 09:40:58: EPOCH 4 - PROGRESS: at 23.75% examples, 264885 words/s, in_qsize 6, out_qsize 1
# INFO - 09:40:59: EPOCH 4 - PROGRESS: at 26.16% examples, 267988 words/s, in_qsize 5, out_qsize 0
# INFO - 09:41:00: EPOCH 4 - PROGRESS: at 28.22% examples, 266878 words/s, in_qsize 5, out_qsize 0
# INFO - 09:41:01: EPOCH 4 - PROGRESS: at 30.16% examples, 265132 words/s, in_qsize 6, out_qsize 0
# INFO - 09:41:02: EPOCH 4 - PROGRESS: at 32.10% examples, 263416 words/s, in_qsize 6, out_qsize 0
# INFO - 09:41:03: EPOCH 4 - PROGRESS: at 34.10% examples, 262105 words/s, in_qsize 6, out_qsize 0
# INFO - 09:41:04: EPOCH 4 - PROGRESS: at 36.27% examples, 262837 words/s, in_qsize 6, out_qsize 0
# INFO - 09:41:05: EPOCH 4 - PROGRESS: at 38.45% examples, 262968 words/s, in_qsize 6, out_qsize 1
# INFO - 09:41:06: EPOCH 4 - PROGRESS: at 40.45% examples, 261988 words/s, in_qsize 5, out_qsize 0
# INFO - 09:41:07: EPOCH 4 - PROGRESS: at 42.33% examples, 260718 words/s, in_qsize 5, out_qsize 1
# INFO - 09:41:08: EPOCH 4 - PROGRESS: at 44.44% examples, 260898 words/s, in_qsize 5, out_qsize 0
# INFO - 09:41:09: EPOCH 4 - PROGRESS: at 46.85% examples, 262747 words/s, in_qsize 5, out_qsize 0
# INFO - 09:41:10: EPOCH 4 - PROGRESS: at 49.21% examples, 263993 words/s, in_qsize 5, out_qsize 0
# INFO - 09:41:11: EPOCH 4 - PROGRESS: at 51.38% examples, 264242 words/s, in_qsize 4, out_qsize 1
# INFO - 09:41:12: EPOCH 4 - PROGRESS: at 53.09% examples, 262042 words/s, in_qsize 6, out_qsize 0
# INFO - 09:41
30: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:42:30: EPOCH - 5 : training on 17005207 raw words (12506348 effective words) took 53.3s, 234789 effective words/s
# INFO - 09:42:30: training on a 85026035 raw words (62532593 effective words) took 270.8s, 230938 effective words/s

# %% [markdown]
# ```Word2Vec``` without ```sentences``` or ```corpus``` is initialization only, should be trained

# %%
model = Word2Vec()
model.build_vocab(data)
model.train(data)

# %% [markdown]
# **Save and load model**

# %%
model.save('w2v_newmodel')
model = Word2Vec.load('w2v_newmodel')
# Out:
# INFO - 21:38:12: saving Word2Vec object under w2v_newmodel, separately None
# INFO - 21:38:12: not storing attribute vectors_norm
# INFO - 21:38:12: not storing attribute cum_table
# INFO - 21:38:14: saved w2v_newmodel
# INFO - 21:38:14: loading Word2Vec object from w2v_newmodel
# INFO - 21:38:17: loading wv recursively from w2v_newmodel.wv.* with mmap=None
# INFO - 21:38:17: setting ignored attribute vectors_norm to None
# INFO - 21:38:17: loading vocabulary recursively from w2v_newmodel.vocabulary.* with mmap=None
# INFO - 21:38:17: loading trainables recursively from w2v_newmodel.trainables.* with mmap=None
# INFO - 21:38:17: setting ignored attribute cum_table to None
# INFO - 21:38:17: loaded w2v_newmodel

# %% [markdown]
# You can **continue training**

# %%
model.train([["hello", "world"]], total_examples=1, epochs=1)
# Out:
# WARNING - 21:38:12: Effective 'alpha' higher than previous training cycles
# INFO - 21:38:12: training model with 3 workers on 71290 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# INFO - 21:38:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 21:38:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 21:38:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 21:38:12: EPOCH - 1 : training on 2 raw words (2 effective words) took 0.0s, 294 effective words/s
# INFO - 21:38:12: training on a 2 raw words (2 effective words) took 0.0s, 103 effective words/s
# WARNING - 21:38:12: under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# (2, 2)

# %% [markdown]
# **Word2vec input**
#
#
# 1) Parameter ```sentences```
#
# Gensim’s word2vec expects a sequence of sentences as its input. Each sentence a list of words
#
#    1.1 *List of list of tokens*

# %%
input1 = [['first', 'sentence'], ['second', 'sentence']]
model1 = Word2Vec(input1, min_count=1)
# Out:
# INFO - 21:44:41: collecting all words and their counts
# INFO - 21:44:41: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 21:44:41: collected 3 word types from a corpus of 4 raw words and 2 sentences
# INFO - 21:44:41: Loading a fresh vocabulary
# INFO - 21:44:41: effective_min_count=1 retains 3 unique words (100% of original 3, drops 0)
# INFO - 21:44:41: effective_min_count=1 leaves 4 word corpus (100% of original 4, drops 0)
# INFO - 21:44:41: deleting the raw counts dictionary of 3 items
# INFO - 21:44:41: sample=0.001 downsamples 3 most-common words
# INFO - 21:44:41: downsampling leaves estimated 0 word corpus (5.7% of prior 4)
# INFO - 21:44:41: estimated required memory for 3 words and 100 dimensions: 3900 bytes
# INFO - 21:44:41: resetting layer weights
# INFO - 21:44:41: training model with 3 workers on 3 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# INFO - 21:44:41: worker thread finished; awaiting finish of 2 more threads
# INFO - 21:44:41: worker thread finished; awaiting finish of 1 more threads
# INFO - 21:44:41: worker thread finished; awaiting finish of 0 more threads
# INFO - 21:44:41: EPOCH - 1 : training on 4 raw words (0 effective words) took 0.0s, 0 effective words/s
# INFO - 21:44:41: worker thread finished; awaiting finish of 2 more threads
# INFO - 21:44:41: worker thread finished; awaiting finish of 1 more threads
# INFO - 21:44:41: worker thread finished; awaiting finish of 0 more threads
# INFO - 21:44:41: EPOCH - 2 : training on 4 raw words (0 effective words) took 0.0s, 0 effective words/s
# INFO - 21:44:41: worker thread finished; awaiting finish of 2 more threads
# INFO - 21:44:41: worker thread finished; awaiting finish of 1 more threads
# INFO - 21:44:41: worker thread finished; awaiting finish of 0 more threads
# INFO - 21:44:41: EPOCH - 3 : training on 4 raw words (1 effective words) took 0.0s, 144 effective words/s
# INFO - 21:44:41: worker thread finished; awaiting finish of 2 more threads
# INFO - 21:44:41: worker thread finished; awaiting finish of 1 more threads
# INFO - 21:44:41: worker thread finished; awaiting finish of 0 more threads
# INFO - 21:44:41: EPOCH - 4 : training on 4 raw words (0 effective words) took 0.0s, 0 effective words/s
# INFO - 21:44:42: worker thread finished; awaiting finish of 2 more threads
# INFO - 21:44:42: worker thread finished; awaiting finish of 1 more threads
# INFO - 21:44:42: worker thread finished; awaiting finish of 0 more threads
# INFO - 21:44:42: EPOCH - 5 : training on 4 raw words (0 effective words) took 0.0s, 0 effective words/s
# INFO - 21:44:42: training on a 20 raw words (1 effective words) took 0.1s, 12 effective words/s
# WARNING - 21:44:42: under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %% [markdown]
# It also could be in any other language, e.g. Russian:

# %%
input2 = [['первое', 'предложение'], ['второе', 'предложение']]
model2 = Word2Vec(input2, min_count=1)

# %% [markdown]
# 1.2 Gensim only requires that the input must provide sentences sequentially, when iterated over. *No need to keep everything in RAM*

# %%
class MySentences(object):
    def __init__(self, dirname):
        self.dirname = dirname
 
    def __iter__(self):
        for fname in os.listdir(self.dirname):
            for line in open(os.path.join(self.dirname, fname)):
                yield line.split()
                
input2 = MySentences('/some/directory') # a memory-friendly iterator
model = gensim.models.Word2Vec(input2)

# %% [markdown]
# See [BrownCorpus](https://radimrehurek.com/gensim/models/word2vec.html#gensim.models.word2vec.BrownCorpus), [Text8Corpus](https://radimrehurek.com/gensim/models/word2vec.html#gensim.models.word2vec.Text8Corpus) or [LineSentence](https://radimrehurek.com/gensim/models/word2vec.html#gensim.models.word2vec.LineSentence) in word2vec module for such examples.
#
# BrownCorpus and Text8Corpus were implemented special for BrownCorpus and Text8 datasets. Text8 corpus, for example, consists of one line of cleaned and joined wikipedia articles.
#
# LineSentence iterate over a file that contains sentences: one line = one sentence. Words must be already preprocessed and separated by whitespace.

# %%
import gensim
from gensim.test.utils import datapath
from gensim.models.word2vec import LineSentence

input3 = LineSentence(datapath('lee_background.cor'))
model = gensim.models.Word2Vec(input3)
# Out:
# INFO - 09:43:35: collecting all words and their counts
# INFO - 09:43:35: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 09:43:35: collected 10781 word types from a corpus of 59890 raw words and 300 sentences
# INFO - 09:43:35: Loading a fresh vocabulary
# INFO - 09:43:35: effective_min_count=5 retains 1762 unique words (16% of original 10781, drops 9019)
# INFO - 09:43:35: effective_min_count=5 leaves 46084 word corpus (76% of original 59890, drops 13806)
# INFO - 09:43:35: deleting the raw counts dictionary of 10781 items
# INFO - 09:43:35: sample=0.001 downsamples 45 most-common words
# INFO - 09:43:35: downsampling leaves estimated 32610 word corpus (70.8% of prior 46084)
# INFO - 09:43:35: estimated required memory for 1762 words and 100 dimensions: 2290600 bytes
# INFO - 09:43:35: resetting layer weights
# INFO - 09:43:38: training model with 3 workers on 1762 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# INFO - 09:43:38: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:43:38: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:43:38: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:43:38: EPOCH - 1 : training on 59890 raw words (32495 effective words) took 0.2s, 133987 effective words/s
# INFO - 09:43:39: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:43:39: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:43:39: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:43:39: EPOCH - 2 : training on 59890 raw words (32584 effective words) took 0.3s, 120293 effective words/s
# INFO - 09:43:39: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:43:39: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:43:39: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:43:39: EPOCH - 3 : training on 59890 raw words (32654 effective words) took 0.3s, 117086 effective words/s
# INFO - 09:43:40: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:43:40: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:43:40: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:43:40: EPOCH - 4 : training on 59890 raw words (32649 effective words) took 0.3s, 112400 effective words/s
# INFO - 09:43:40: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:43:40: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:43:40: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:43:40: EPOCH - 5 : training on 59890 raw words (32618 effective words) took 0.3s, 129786 effective words/s
# INFO - 09:43:40: training on a 299450 raw words (163000 effective words) took 2.1s, 77495 effective words/s

# %% [markdown]
# 2. Parameter ```corpus_file``` - path to a corpus file in LineSentence format
#
# If corpus is in right format, parameter corpus_file may be passed instead of last cell

# %% [markdown]
# ## Exploring the model

# %% [markdown]
# - Extract the trained word vectors from model.wv:

# %%
w2v_model.wv['topic']
# Out:
# C:\Users\v00524754\AppData\Local\Continuum\miniconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# array([-0.04278 ,  0.79271 , -0.70087 , -0.023487,  0.24581 ,  0.24413 ,
#        -0.10713 , -0.51894 , -0.17387 , -0.15821 , -0.90392 , -0.33753 ,
#        -0.13262 ,  0.67051 ,  0.93457 ,  0.046388, -0.26368 , -0.23655 ,
#         0.80884 ,  0.1048  ,  0.43985 , -0.068909,  0.83773 ,  1.0383  ,
#         1.0378  , -1.0609  , -0.015392,  0.39162 , -0.1175  ,  0.40644 ,
#         1.9836  , -0.41525 , -0.050877, -1.2321  , -0.69079 , -0.35601 ,
#        -0.75549 ,  0.94668 , -0.84225 ,  0.095134, -0.092177, -0.13833 ,
#        -0.30647 ,  0.89785 ,  0.071583,  0.31083 ,  0.88585 ,  1.1397  ,
#        -0.19138 ,  0.27392 ], dtype=float32)

# %% [markdown]
# - Similarity

# %%
w2v_model.wv.most_similar(positive = ['topic'])
# Out:
# C:\Users\v00524754\AppData\Local\Continuum\miniconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# [('topics', 0.8801343441009521),
#  ('discussion', 0.8731067180633545),
#  ('debates', 0.7824684381484985),
#  ('discussing', 0.7815945744514465),
#  ('questions', 0.7759715914726257),
#  ('debate', 0.7666820883750916),
#  ('context', 0.7591571807861328),
#  ('subject', 0.7455185651779175),
#  ('question', 0.733422040939331),
#  ('focusing', 0.7311854362487793)]

# %%
model = w2v_model

# %%
print('Similarity between (walk, walking): ', model.wv.similarity('walk', 'walking'))
print('Similarity between (duck, ducks): ', model.wv.similarity('duck', 'ducks'))
print('Similarity between (banana, pear): ', model.wv.similarity('banana', 'pear'))
print()
print('Similarity between (banana, sky): ', model.wv.similarity('banana', 'sky'))
print('Similarity between (walk, lie): ', model.wv.similarity('walk', 'lie'))
print('Similarity between (dark, slow): ', model.wv.similarity('dark', 'slow'))
# Out:
# Similarity between (walk, walking):  0.90261763
# Similarity between (duck, ducks):  0.6012516
# Similarity between (banana, pear):  0.64588785
#
# Similarity between (banana, sky):  0.08188744
# Similarity between (walk, lie):  0.5613729
# Similarity between (dark, slow):  0.38198376
# C:\Users\v00524754\AppData\Local\Continuum\miniconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# C:\Users\v00524754\AppData\Local\Continuum\miniconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#
# C:\Users\v00524754\AppData\Local\Continuum\miniconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\v00524754\AppData\Local\Continuum\miniconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# C:\Users\v00524754\AppData\Local\Continuum\miniconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#
# C:\Users\v00524754\AppData\Local\Continuum\miniconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   import sys

# %% [markdown]
# - Analogy

# %%
model.wv.most_similar(positive = ['lower', 'tall'], negative = ['low'])
# Out:
# C:\Users\v00524754\AppData\Local\Continuum\miniconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# [('marble', 0.7085803747177124),
#  ('stands', 0.7059853672981262),
#  ('wooden', 0.7055877447128296),
#  ('conical', 0.6954946517944336),
#  ('shaped', 0.6953530311584473),
#  ('feet', 0.6921709775924683),
#  ('atop', 0.6903060674667358),
#  ('spire', 0.6899060010910034),
#  ('upright', 0.6865338683128357),
#  ('arches', 0.683355450630188)]

# %%
model.wv.most_similar(positive = ['mother', 'man'], negative = ['woman'])
# Out:
# C:\Users\v00524754\AppData\Local\Continuum\miniconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# [('father', 0.9208111763000488),
#  ('friend', 0.9095532894134521),
#  ('son', 0.8972886800765991),
#  ('brother', 0.8844174742698669),
#  ('uncle', 0.8572986721992493),
#  ('husband', 0.8507049679756165),
#  ('wife', 0.8354371786117554),
#  ('himself', 0.8331096172332764),
#  ('daughter', 0.8320738077163696),
#  ('him', 0.8309528827667236)]

# %% [markdown]
# - Matching

# %%
print(model.wv.doesnt_match(['car', 'airplane', 'bed']), " doesn't match to [car, airplane]")
print(model.wv.doesnt_match(['red', 'blue', 'roof']), " doesn't match to [red, blue]")
# Out:
# bed  doesn't match to [car, airplane]
# roof  doesn't match to [red, blue]
# C:\Users\v00524754\AppData\Local\Continuum\miniconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# C:\Users\v00524754\AppData\Local\Continuum\miniconda3\lib\site-packages\gensim\models\keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# C:\Users\v00524754\AppData\Local\Continuum\miniconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %% [markdown]
# ## Compare with other pretrained embeddings

# %%
fasttext_model300 = api.load('fasttext-wiki-news-subwords-300')
word2vec_model300 = api.load('word2vec-google-news-300')
glove_model300 = api.load('glove-wiki-gigaword-300')
# Out:
# [--------------------------------------------------] 1.2% 11.3/958.4MB downloaded
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-1212eab64a2d> in <module>
# ----> 1 fasttext_model300 = api.load('fasttext-wiki-news-subwords-300')
#       2 word2vec_model300 = api.load('word2vec-google-news-300')
#       3 glove_model300 = api.load('glove-wiki-gigaword-300')
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\gensim\downloader.py in load(name, return_path)
#     493     path = os.path.join(folder_dir, file_name)
#     494     if not os.path.exists(folder_dir):
# --> 495         _download(name)
#     496
#     497     if return_path:
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\gensim\downloader.py in _download(name)
#     393         fname = "{fname}.gz".format(fname=name)
#     394         dst_path = os.path.join(tmp_dir, fname)
# --> 395         urllib.urlretrieve(url_data, dst_path, reporthook=_progress)
#     396         if _calculate_md5_checksum(dst_path) == _get_checksum(name):
#     397             sys.stdout.write("\n")
#
# ~\AppData\Local\Continuum\miniconda3\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     281                 blocknum += 1
#     282                 if reporthook:
# --> 283                     reporthook(blocknum, bs, size)
#     284
#     285     if size >= 0 and read < size:
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\gensim\downloader.py in _progress(chunks_downloaded, chunk_size, total_size, part, total_parts)
#     126                 round(float(total_size) / (1024 * 1024), 1))
#     127         )
# --> 128         sys.stdout.flush()
#     129     else:
#     130         sys.stdout.write(
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\ipykernel\iostream.py in flush(self)
#     349                 self.pub_thread.schedule(evt.set)
#     350                 # and give a timeout to avoid
# --> 351                 if not evt.wait(self.flush_timeout):
#     352                     # write directly to __stderr__ instead of warning because
#     353                     # if this is happening sys.stderr may be the problem.
#
# ~\AppData\Local\Continuum\miniconda3\lib\threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~\AppData\Local\Continuum\miniconda3\lib\threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# To define which one performs better using the respective model's evaluate_word_analogies()
#
# Compute performance of the model on an analogy test set. The accuracy is reported (printed to log and returned as a score) for each section separately, plus there’s one aggregate summary at the end.
#
# Input:
# - ```analogies``` (str) – Path to file, where lines are 4-tuples of words, split into sections by “: SECTION NAME” lines. See [this file](https://github.com/RaRe-Technologies/gensim/blob/develop/docs/notebooks/datasets/questions-words.txt) as example.
#
# Output:
# - ```score``` (float) – The overall evaluation score on the entire evaluation set
#
# - ```sections``` (list of dict of {str : str or list of tuple of (str, str, str, str)}) – Results broken down by each section of the evaluation set. Each dict contains the name of the section under the key ‘section’, and lists of correctly and incorrectly predicted 4-tuples of words under the keys ‘correct’ and ‘incorrect’.

# %%
f = open('questions-words.txt', 'r')
for i in range(5):
    print(f.readline())
f.close()
# Out:
# : capital-common-countries
#
# Athens Greece Baghdad Iraq
#
# Athens Greece Bangkok Thailand
#
# Athens Greece Beijing China
#
# Athens Greece Berlin Germany

# %%
word2vec_model300.evaluate_word_analogies(analogies='questions-words.txt')[0]

# fasttext_accuracy
fasttext_model300.evaluate_word_analogies(analogies='questions-words.txt')[0]

# GloVe accuracy
glove_model300.evaluate_word_analogies(analogies='questions-words.txt')[0]
# Out:
# 0.7401448525607863
# 0.8827876424099353
# 0.7195422354510931

# %% [markdown]
# ## Doc2Vec
#
# Unlike Word2Vec, a Doc2Vec model provides a vectorised representation of a group of words taken collectively as a single unit. It is not a simple average of the word vectors of the words in the sentence.
#
# The training data for ```Doc2Vec``` should be a list of ```TaggedDocuments```. To create one, we pass a list of words and a unique integer as input to the ```models.doc2vec.TaggedDocument()```.

# %%
#prepare dataset
def create_tagged_document(list_of_list_of_words):
    for i, list_of_words in enumerate(list_of_list_of_words):
        yield TaggedDocument(list_of_words, [i])

dataset = api.load("text8")
data = [d for d in dataset]

train_data = list(create_tagged_document(data))
print(train_data[:1])
# Out:
# [TaggedDocument(words=['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term', 'is', 'still', 'used', 'in', 'a', 'pejorative', 'way', 'to', 'describe', 'any', 'act', 'that', 'used', 'violent', 'means', 'to', 'destroy', 'the', 'organization', 'of', 'society', 'it', 'has', 'also', 'been', 'taken', 'up', 'as', 'a', 'positive', 'label', 'by', 'self', 'defined', 'anarchists', 'the', 'word', 'anarchism', 'is', 'derived', 'from', 'the', 'greek', 'without', 'archons', 'ruler', 'chief', 'king', 'anarchism', 'as', 'a', 'political', 'philosophy', 'is', 'the', 'belief', 'that', 'rulers', 'are', 'unnecessary', 'and', 'should', 'be', 'abolished', 'although', 'there', 'are', 'differing', 'interpretations', 'of', 'what', 'this', 'means', 'anarchism', 'also', 'refers', 'to', 'related', 'social', 'movements', 'that', 'advocate', 'the', 'elimination', 'of', 'authoritarian', 'institutions', 'particularly', 'the', 'state', 'the', 'word', 'anarchy', 'as', 'most', 'anarchists', 'use', 'it', 'does', 'not', 'imply', 'chaos', 'nihilism', 'or', 'anomie', 'but', 'rather', 'a', 'harmonious', 'anti', 'authoritarian', 'society', 'in', 'place', 'of', 'what', 'are', 'regarded', 'as', 'authoritarian', 'political', 'structures', 'and', 'coercive', 'economic', 'institutions', 'anarchists', 'advocate', 'social', 'relations', 'based', 'upon', 'voluntary', 'association', 'of', 'autonomous', 'individuals', 'mutual', 'aid', 'and', 'self', 'governance', 'while', 'anarchism', 'is', 'most', 'easily', 'defined', 'by', 'what', 'it', 'is', 'against', 'anarchists', 'also', 'offer', 'positive', 'visions', 'of', 'what', 'they', 'believe', 'to', 'be', 'a', 'truly', 'free', 'society', 'however', 'ideas', 'about', 'how', 'an', 'anarchist', 'society', 'might', 'work', 'vary', 'considerably', 'especially', 'with', 'respect', 'to', 'economics', 'there', 'is', 'also', 'disagreement', 'about', 'how', 'a', 'free', 'society', 'might', 'be', 'brought', 'about', 'origins', 'and', 'predecessors', 'kropotkin', 'and', 'others', 'argue', 'that', 'before', 'recorded', 'history', 'human', 'society', 'was', 'organized', 'on', 'anarchist', 'principles', 'most', 'anthropologists', 'follow', 'kropotkin', 'and', 'engels', 'in', 'believing', 'that', 'hunter', 'gatherer', 'bands', 'were', 'egalitarian', 'and', 'lacked', 'division', 'of', 'labour', 'accumulated', 'wealth', 'or', 'decreed', 'law', 'and', 'had', 'equal', 'access', 'to', 'resources', 'william', 'godwin', 'anarchists', 'including', 'the', 'the', 'anarchy', 'organisation', 'and', 'rothbard', 'find', 'anarchist', 'attitudes', 'in', 'taoism', 'from', 'ancient', 'china', 'kropotkin', 'found', 'similar', 'ideas', 'in', 'stoic', 'zeno', 'of', 'citium', 'according', 'to', 'kropotkin', 'zeno', 'repudiated', 'the', 'omnipotence', 'of', 'the', 'state', 'its', 'intervention', 'and', 'regimentation', 'and', 'proclaimed', 'the', 'sovereignty', 'of', 'the', 'moral', 'law', 'of', 'the', 'individual', 'the', 'anabaptists', 'of', 'one', 'six', 'th', 'century', 'europe', 'are', 'sometimes', 'considered', 'to', 'be', 'religious', 'forerunners', 'of', 'modern', 'anarchism', 'bertrand', 'russell', 'in', 'his', 'history', 'of', 'western', 'philosophy', 'writes', 'that', 'the', 'anabaptists', 'repudiated', 'all', 'law', 'since', 'they', 'held', 'that', 'the', 'good', 'man', 'will', 'be', 'guided', 'at', 'every', 'moment', 'by', 'the', 'holy', 'spirit', 'from', 'this', 'premise', 'they', 'arrive', 'at', 'communism', 'the', 'diggers', 'or', 'true', 'levellers', 'were', 'an', 'early', 'communistic', 'movement', 'during', 'the', 'time', 'of', 'the', 'english', 'civil', 'war', 'and', 'are', 'considered', 'by', 'some', 'as', 'forerunners', 'of', 'modern', 'anarchism', 'in', 'the', 'modern', 'era', 'the', 'first', 'to', 'use', 'the', ...

# %%
#Train model
model = Doc2Vec(vector_size=50, min_count=1, epochs=40)
model.build_vocab(train_data)
model.train(train_data, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# WARNING - 09:55:12: consider setting layer size to a multiple of 4 for greater performance
# INFO - 09:55:12: collecting all words and their counts
# INFO - 09:55:12: PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# INFO - 09:55:35: collected 253854 word types and 1701 unique tags from a corpus of 1701 examples and 17005207 words
# INFO - 09:55:35: Loading a fresh vocabulary
# INFO - 09:55:39: effective_min_count=1 retains 253854 unique words (100% of original 253854, drops 0)
# INFO - 09:55:39: effective_min_count=1 leaves 17005207 word corpus (100% of original 17005207, drops 0)
# INFO - 09:55:44: deleting the raw counts dictionary of 253854 items
# INFO - 09:55:44: sample=0.001 downsamples 36 most-common words
# INFO - 09:55:44: downsampling leaves estimated 12819131 word corpus (75.4% of prior 17005207)
# INFO - 09:55:47: estimated required memory for 253854 words and 50 dimensions: 228808800 bytes
# INFO - 09:55:47: resetting layer weights
# INFO - 10:01:37: training model with 3 workers on 253854 vocabulary and 50 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# INFO - 10:01:38: EPOCH 1 - PROGRESS: at 1.47% examples, 176837 words/s, in_qsize 6, out_qsize 0
# INFO - 10:01:39: EPOCH 1 - PROGRESS: at 3.23% examples, 200054 words/s, in_qsize 5, out_qsize 0
# INFO - 10:01:40: EPOCH 1 - PROGRESS: at 5.17% examples, 213081 words/s, in_qsize 6, out_qsize 0
# INFO - 10:01:41: EPOCH 1 - PROGRESS: at 7.11% examples, 218314 words/s, in_qsize 5, out_qsize 0
# INFO - 10:01:42: EPOCH 1 - PROGRESS: at 8.94% examples, 220682 words/s, in_qsize 6, out_qsize 0
# INFO - 10:01:43: EPOCH 1 - PROGRESS: at 10.46% examples, 213888 words/s, in_qsize 5, out_qsize 0
# INFO - 10:01:44: EPOCH 1 - PROGRESS: at 12.17% examples, 214412 words/s, in_qsize 6, out_qsize 0
# INFO - 10:01:45: EPOCH 1 - PROGRESS: at 13.82% examples, 213048 words/s, in_qsize 6, out_qsize 0
# INFO - 10:01:46: EPOCH 1 - PROGRESS: at 15.87% examples, 218112 words/s, in_qsize 5, out_qsize 0
# INFO - 10:01
words/s, in_qsize 4, out_qsize 1
# INFO - 10:02:28: EPOCH 1 - PROGRESS: at 74.43% examples, 187373 words/s, in_qsize 4, out_qsize 1
# INFO - 10:02:29: EPOCH 1 - PROGRESS: at 76.43% examples, 188325 words/s, in_qsize 5, out_qsize 0
# INFO - 10:02:30: EPOCH 1 - PROGRESS: at 78.07% examples, 188165 words/s, in_qsize 6, out_qsize 0
# INFO - 10:02:31: EPOCH 1 - PROGRESS: at 79.78% examples, 188700 words/s, in_qsize 6, out_qsize 0
# INFO - 10:02:32: EPOCH 1 - PROGRESS: at 81.54% examples, 189338 words/s, in_qsize 4, out_qsize 0
# INFO - 10:02:33: EPOCH 1 - PROGRESS: at 82.66% examples, 188487 words/s, in_qsize 5, out_qsize 1
# INFO - 10:02:34: EPOCH 1 - PROGRESS: at 84.36% examples, 189042 words/s, in_qsize 6, out_qsize 0
# INFO - 10:02:35: EPOCH 1 - PROGRESS: at 85.95% examples, 189291 words/s, in_qsize 4, out_qsize 1
# INFO - 10:02:36: EPOCH 1 - PROGRESS: at 87.71% examples, 189912 words/s, in_qsize 6, out_qsize 0
# INFO - 10:02:37: EPOCH 1 - PROGRESS: at 89.42% examples, 190347 words/s, in_qsize 5, out_qsize 0
# INFO - 10:02:38: EPOCH 1 - PROGRESS: at 91.18% examples, 190782 words/s, in_qsize 4, out_qsize 1
# INFO - 10:02:39: EPOCH 1 - PROGRESS: at 92.95% examples, 191212 words/s, in_qsize 6, out_qsize 0
# INFO - 10:02:41: EPOCH 1 - PROGRESS: at 94.83% examples, 191352 words/s, in_qsize 4, out_qsize 1
# INFO - 10:02:42: EPOCH 1 - PROGRESS: at 96.18% examples, 191071 words/s, in_qsize 5, out_qsize 0
# INFO - 10:02:43: EPOCH 1 - PROGRESS: at 97.35% examples, 190400 words/s, in_qsize 5, out_qsize 0
# INFO - 10:02:44: EPOCH 1 - PROGRESS: at 98.71% examples, 190076 words/s, in_qsize 6, out_qsize 0
# INFO - 10:02:44: worker thread finished; awaiting finish of 2 more threads
# INFO - 10:02:44: worker thread finished; awaiting finish of 1 more threads
# INFO - 10:02:44: worker thread finished; awaiting finish of 0 more threads
# INFO - 10:02:45: EPOCH - 1 : training on 17005207 raw words (12820334 effective words) took 67.4s, 190268 effective words/s
# INFO - 10:02:46: EPOCH 2 - PROGRESS: at 1.47% examples, 189852 words/s, in_qsize 5, out_qsize 0
# INFO - 10:02:47: EPOCH 2 - PROGRESS: at 3.47% examples, 217220 words/s, in_qsize 6, out_qsize 0
# INFO - 10:02:48: EPOCH 2 - PROGRESS: at 5.11% examples, 213669 words/s, in_qsize 6, out_qsize 1
# INFO - 10:02:49: EPOCH 2 - PROGRESS: at 6.41% examples, 200442 words/s, in_qsize 5, out_qsize 0
# INFO - 10:02:50: EPOCH 2 - PROGRESS: at 8.29% examples, 205678 words/s, in_qsize 5, out_qsize 0
# INFO - 10:02:51: EPOCH 2 - PROGRESS: at 10.17% examples, 209203 words/s, in_qsize 6, out_qsize 0
# INFO - 10:02:52: EPOCH 2 - PROGRESS: at 11.88% examples, 210481 words/s, in_qsize 6, out_qsize 0
# INFO - 10:02:53: EPOCH 2 - PROGRESS: at 13.52% examples, 209096 words/s, in_qsize 3, out_qsize 2
# INFO - 10:02:54: EPOCH 2 - PROGRESS: at 15.11% examples, 207823 words/s, in_qsize 5, out_qsize 0
# INFO - 10:02:55: EPOCH 2 - PROGRESS: at 16.64% examples, 206563 words/s, in_qsize 5, out_qsize 0
# INFO - 10:02:56: EPOCH 2 - PROGRESS: at 18.11% examples, 204596 words/s, in_qsize 5, out_qsize 0
# INFO - 10:02:57: EPOCH 2 - PROGRESS: at 19.52% examples, 201395 words/s, in_qsize 5, out_qsize 0
# INFO - 10:02:58: EPOCH 2 - PROGRESS: at 20.99% examples, 200404 words/s, in_qsize 5, out_qsize 0
# INFO - 10:02:59: EPOCH 2 - PROGRESS: at 22.75% examples, 202097 words/s, in_qsize 6, out_qsize 0
# INFO - 10:03:00: EPOCH 2 - PROGRESS: at 23.99% examples, 199371 words/s, in_qsize 5, out_qsize 0
# INFO - 10:03:01: EPOCH 2 - PROGRESS: at 25.22% examples, 196348 words/s, in_qsize 6, out_qsize 0
# INFO - 10:03:02: EPOCH 2 - PROGRESS: at 26.16% examples, 191952 words/s, in_qsize 5, out_qsize 0
# INFO - 10:03:03: EPOCH 2 - PROGRESS: at 27.57% examples, 191103 words/s, in_qsize 4, out_qsize 1
# INFO - 10:03:04: EPOCH 2 - PROGRESS: at 29.28% examples, 192371 words/s, in_qsize 5, out_qsize 0
# INFO - 10:03:05: EPOCH 2 - PROGRESS: at 30.86% examples, 192180 words/s, in_qsize 5, out_qsize 0
# INFO - 10:03:06: EPOCH 2 - PROGRESS: at 32.22% examples, 189491 words/s, in_qsize 6, out_qsize 1
# INFO - 10:03:07: EPOCH 2 - PROGRESS: at 33.39% examples, 187686 words/s, in_qsize 5, out_qsize 0
# INFO - 10:03
words/s, in_qsize 6, out_qsize 0
# INFO - 10:03:52: EPOCH 2 - PROGRESS: at 95.88% examples, 182779 words/s, in_qsize 4, out_qsize 1
# INFO - 10:03:53: EPOCH 2 - PROGRESS: at 97.24% examples, 182539 words/s, in_qsize 5, out_qsize 0
# INFO - 10:03:54: EPOCH 2 - PROGRESS: at 98.77% examples, 182528 words/s, in_qsize 5, out_qsize 0
# INFO - 10:03:55: worker thread finished; awaiting finish of 2 more threads
# INFO - 10:03:55: worker thread finished; awaiting finish of 1 more threads
# INFO - 10:03:55: worker thread finished; awaiting finish of 0 more threads
# INFO - 10:03:55: EPOCH - 2 : training on 17005207 raw words (12820402 effective words) took 70.3s, 182254 effective words/s
# INFO - 10:03:56: EPOCH 3 - PROGRESS: at 2.00% examples, 255813 words/s, in_qsize 6, out_qsize 0
# INFO - 10:03:57: EPOCH 3 - PROGRESS: at 3.59% examples, 226862 words/s, in_qsize 6, out_qsize 0
# INFO - 10:03:58: EPOCH 3 - PROGRESS: at 5.76% examples, 241629 words/s, in_qsize 5, out_qsize 1
# INFO - 10:03:59: EPOCH 3 - PROGRESS: at 7.47% examples, 234510 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:00: EPOCH 3 - PROGRESS: at 9.17% examples, 230136 words/s, in_qsize 6, out_qsize 0
# INFO - 10:04:01: EPOCH 3 - PROGRESS: at 11.11% examples, 232228 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:02: EPOCH 3 - PROGRESS: at 12.82% examples, 230175 words/s, in_qsize 6, out_qsize 0
# INFO - 10:04:03: EPOCH 3 - PROGRESS: at 14.81% examples, 232095 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:04: EPOCH 3 - PROGRESS: at 16.75% examples, 231595 words/s, in_qsize 3, out_qsize 2
# INFO - 10:04:05: EPOCH 3 - PROGRESS: at 18.17% examples, 225753 words/s, in_qsize 6, out_qsize 0
# INFO - 10:04:06: EPOCH 3 - PROGRESS: at 19.69% examples, 221635 words/s, in_qsize 6, out_qsize 0
# INFO - 10:04:07: EPOCH 3 - PROGRESS: at 21.52% examples, 220837 words/s, in_qsize 5, out_qsize 2
# INFO - 10:04:08: EPOCH 3 - PROGRESS: at 23.34% examples, 221198 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:09: EPOCH 3 - PROGRESS: at 25.28% examples, 223092 words/s, in_qsize 6, out_qsize 0
# INFO - 10:04:10: EPOCH 3 - PROGRESS: at 26.98% examples, 222982 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:11: EPOCH 3 - PROGRESS: at 28.22% examples, 218702 words/s, in_qsize 6, out_qsize 0
# INFO - 10:04:13: EPOCH 3 - PROGRESS: at 29.81% examples, 217282 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:14: EPOCH 3 - PROGRESS: at 31.75% examples, 218821 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:15: EPOCH 3 - PROGRESS: at 33.45% examples, 218895 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:16: EPOCH 3 - PROGRESS: at 35.33% examples, 219863 words/s, in_qsize 5, out_qsize 1
# INFO - 10:04:17: EPOCH 3 - PROGRESS: at 37.10% examples, 220107 words/s, in_qsize 6, out_qsize 0
# INFO - 10:04:18: EPOCH 3 - PROGRESS: at 38.27% examples, 216978 words/s, in_qsize 6, out_qsize 0
# INFO - 10:04:19: EPOCH 3 - PROGRESS: at 39.92% examples, 216387 words/s, in_qsize 6, out_qsize 0
# INFO - 10:04:20: EPOCH 3 - PROGRESS: at 41.68% examples, 216573 words/s, in_qsize 6, out_qsize 0
# INFO - 10:04:21: EPOCH 3 - PROGRESS: at 43.74% examples, 218251 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:22: EPOCH 3 - PROGRESS: at 45.68% examples, 219285 words/s, in_qsize 6, out_qsize 0
# INFO - 10:04:23: EPOCH 3 - PROGRESS: at 47.21% examples, 218224 words/s, in_qsize 5, out_qsize 1
# INFO - 10:04:24: EPOCH 3 - PROGRESS: at 48.85% examples, 217732 words/s, in_qsize 4, out_qsize 1
# INFO - 10:04:25: EPOCH 3 - PROGRESS: at 50.91% examples, 219082 words/s, in_qsize 4, out_qsize 1
# INFO - 10:04:26: EPOCH 3 - PROGRESS: at 52.85% examples, 219992 words/s, in_qsize 6, out_qsize 0
# INFO - 10:04:27: EPOCH 3 - PROGRESS: at 54.67% examples, 220470 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:28: EPOCH 3 - PROGRESS: at 56.38% examples, 220413 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:29: EPOCH 3 - PROGRESS: at 58.02% examples, 219963 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:30: EPOCH 3 - PROGRESS: at 59.61% examples, 219281 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:31: EPOCH 3 - PROGRESS: at 61.55% examples, 219894 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:32: EPOCH 3 - PROGRESS: at 63.32% examples, 219921 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:33: EPOCH 3 - PROGRESS: at 65.43% examples, 221017 words/s, in_qsize 6, out_qsize 0
# INFO - 10:04:34: EPOCH 3 - PROGRESS: at 66.96% examples, 220216 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:35: EPOCH 3 - PROGRESS: at 68.67% examples, 219929 words/s, in_qsize 6, out_qsize 0
# INFO - 10:04:36: EPOCH 3 - PROGRESS: at 70.55% examples, 220396 words/s, in_qsize 6, out_qsize 0
# INFO - 10:04:37: EPOCH 3 - PROGRESS: at 72.55% examples, 221105 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:38: EPOCH 3 - PROGRESS: at 74.54% examples, 221829 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:39: EPOCH 3 - PROGRESS: at 76.43% examples, 221560 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:40: EPOCH 3 - PROGRESS: at 77.95% examples, 220874 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:41: EPOCH 3 - PROGRESS: at 80.01% examples, 221489 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:42: EPOCH 3 - PROGRESS: at 81.54% examples, 220901 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:43: EPOCH 3 - PROGRESS: at 83.54% examples, 221589 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:44: EPOCH 3 - PROGRESS: at 85.36% examples, 221738 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:45: EPOCH 3 - PROGRESS: at 86.89% examples, 221069 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:46: EPOCH 3 - PROGRESS: at 88.77% examples, 221447 words/s, in_qsize 6, out_qsize 0
# INFO - 10:04:47: EPOCH 3 - PROGRESS: at 90.42% examples, 221271 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:48: EPOCH 3 - PROGRESS: at 92.65% examples, 222316 words/s, in_qsize 6, out_qsize 0
# INFO - 10:04:49: EPOCH 3 - PROGRESS: at 94.53% examples, 222591 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:50: EPOCH 3 - PROGRESS: at 96.36% examples, 222748 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:51: EPOCH 3 - PROGRESS: at 97.77% examples, 221937 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:52: EPOCH 3 - PROGRESS: at 99.65% examples, 222140 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:53: worker thread finished; awaiting finish of 2 more threads
# INFO - 10:04:53: worker thread finished; awaiting finish of 1 more threads
# INFO - 10:04:53: worker thread finished; awaiting finish of 0 more threads
# INFO - 10:04:53: EPOCH - 3 : training on 17005207 raw words (12821450 effective words) took 57.7s, 222387 effective words/s
# INFO - 10:04:54: EPOCH 4 - PROGRESS: at 1.65% examples, 207642 words/s, in_qsize 6, out_qsize 0
# INFO - 10:04:55: EPOCH 4 - PROGRESS: at 3.53% examples, 223396 words/s, in_qsize 4, out_qsize 1
# INFO - 10:04:56: EPOCH 4 - PROGRESS: at 5.64% examples, 238215 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:57: EPOCH 4 - PROGRESS: at 7.35% examples, 227141 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:58: EPOCH 4 - PROGRESS: at 9.23% examples, 229301 words/s, in_qsize 5, out_qsize 0
# INFO - 10:04:59: EPOCH 4 - PROGRESS: at 10.93% examples, 226601 words/s, in_qsize 6, out_qsize 0
# INFO - 10:05:00: EPOCH 4 - PROGRESS: at 13.05% examples, 232498 words/s, in_qsize 5, out_qsize 0
# INFO - 10:05:01: EPOCH 4 - PROGRESS: at 14.76% examples, 230514 words/s, in_qsize 5, out_qsize 0
# INFO - 10:05:02: EPOCH 4 - PROGRESS: at 16.34% examples, 226091 words/s, in_qsize 6, out_qsize 0
# INFO - 10:05:03: EPOCH 4 - PROGRESS: at 17.99% examples, 224596 words/s, in_qsize 6, out_qsize 0
# INFO - 10:05:04: EPOCH 4 - PROGRESS: at 19.11% examples, 215791 words/s, in_qsize 5, out_qsize 0
# INFO - 10:05:05: EPOCH 4 - PROGRESS: at 19.75% examples, 204701 words/s, in_qsize 6, out_qsize 0
# INFO - 10:05:06: EPOCH 4 - PROGRESS: at 21.46% examples, 204982 words/s, in_qsize 5, out_qsize 0
# INFO - 10:05:07: EPOCH 4 - PROGRESS: at 22.93% examples, 203757 words/s, in_qsize 5, out_qsize 0
# INFO - 10:05:08: EPOCH 4 - PROGRESS: at 24.28% examples, 200987 words/s, in_qsize 6, out_qsize 0
# INFO - 10:05:09: EPOCH 4 - PROGRESS: at 25.63% examples, 199216 words/s, in_qsize 5, out_qsize 0
# INFO - 10:05:10: EPOCH 4 - PROGRESS: at 27.28% examples, 199654 words/s, in_qsize 6, out_qsize 0
# INFO - 10:05:11: EPOCH 4 - PROGRESS: at 28.92% examples, 200077 words/s, in_qsize 5, out_qsize 0
# INFO - 10:05:12: EPOCH 4 - PROGRESS: at 30.22% examples, 198418 words/s, in_qsize 5, out_qsize 0
# INFO - 10:05
words/s, in_qsize 5, out_qsize 0
# INFO - 10:05:55: EPOCH 4 - PROGRESS: at 97.35% examples, 201320 words/s, in_qsize 4, out_qsize 1
# INFO - 10:05:56: EPOCH 4 - PROGRESS: at 98.30% examples, 199905 words/s, in_qsize 5, out_qsize 0
# INFO - 10:05:57: EPOCH 4 - PROGRESS: at 99.76% examples, 199742 words/s, in_qsize 4, out_qsize 0
# INFO - 10:05:57: worker thread finished; awaiting finish of 2 more threads
# INFO - 10:05:57: worker thread finished; awaiting finish of 1 more threads
# INFO - 10:05:57: worker thread finished; awaiting finish of 0 more threads
# INFO - 10:05:57: EPOCH - 4 : training on 17005207 raw words (12821422 effective words) took 64.2s, 199799 effective words/s
# INFO - 10:05:58: EPOCH 5 - PROGRESS: at 1.18% examples, 152342 words/s, in_qsize 5, out_qsize 0
# INFO - 10:05:59: EPOCH 5 - PROGRESS: at 2.53% examples, 158283 words/s, in_qsize 4, out_qsize 1
# INFO - 10:06:00: EPOCH 5 - PROGRESS: at 4.23% examples, 177178 words/s, in_qsize 5, out_qsize 0
# INFO - 10:06:01: EPOCH 5 - PROGRESS: at 5.41% examples, 169757 words/s, in_qsize 6, out_qsize 0
# INFO - 10:06:02: EPOCH 5 - PROGRESS: at 6.58% examples, 163075 words/s, in_qsize 6, out_qsize 0
# INFO - 10:06:03: EPOCH 5 - PROGRESS: at 7.88% examples, 163244 words/s, in_qsize 4, out_qsize 1
# INFO - 10:06:04: EPOCH 5 - PROGRESS: at 9.52% examples, 169476 words/s, in_qsize 5, out_qsize 1
# INFO - 10:06:05: EPOCH 5 - PROGRESS: at 11.17% examples, 174086 words/s, in_qsize 5, out_qsize 0
# INFO - 10:06:06: EPOCH 5 - PROGRESS: at 12.76% examples, 177328 words/s, in_qsize 6, out_qsize 0
# INFO - 10:06:07: EPOCH 5 - PROGRESS: at 14.29% examples, 178343 words/s, in_qsize 3, out_qsize 2
# INFO - 10:06:08: EPOCH 5 - PROGRESS: at 15.64% examples, 176722 words/s, in_qsize 5, out_qsize 0
# INFO - 10:06:09: EPOCH 5 - PROGRESS: at 17.05% examples, 176773 words/s, in_qsize 5, out_qsize 0
# INFO - 10:06:10: EPOCH 5 - PROGRESS: at 18.52% examples, 177371 words/s, in_qsize 6, out_qsize 0
# INFO - 10:06:11: EPOCH 5 - PROGRESS: at 20.22% examples, 179626 words/s, in_qsize 5, out_qsize 0
# INFO - 10:06:12: EPOCH 5 - PROGRESS: at 21.69% examples, 179752 words/s, in_qsize 3, out_qsize 2
# INFO - 10:06:13: EPOCH 5 - PROGRESS: at 22.81% examples, 177493 words/s, in_qsize 6, out_qsize 0
# INFO - 10:06:14: EPOCH 5 - PROGRESS: at 24.51% examples, 179912 words/s, in_qsize 5, out_qsize 0
# INFO - 10:06:15: EPOCH 5 - PROGRESS: at 26.10% examples, 181264 words/s, in_qsize 4, out_qsize 0
# INFO - 10:06:16: EPOCH 5 - PROGRESS: at 28.10% examples, 185210 words/s, in_qsize 5, out_qsize 0
# INFO - 10:06:17: EPOCH 5 - PROGRESS: at 29.81% examples, 186589 words/s, in_qsize 4, out_qsize 1
# INFO - 10:06:18: EPOCH 5 - PROGRESS: at 31.69% examples, 188979 words/s, in_qsize 5, out_qsize 0
# INFO - 10:06:19: EPOCH 5 - PROGRESS: at 33.33% examples, 189242 words/s, in_qsize 5, out_qsize 0
# INFO - 10:06:20: EPOCH 5 - PROGRESS: at 34.92% examples, 189727 words/s, in_qsize 5, out_qsize 0
# INFO - 10:06:22: EPOCH 5 - PROGRESS: at 36.74% examples, 191250 words/s, in_qsize 4, out_qsize 1
# INFO - 10:06:23: EPOCH 5 - PROGRESS: at 38.51% examples, 192518 words/s, in_qsize 4, out_qsize 0
# INFO - 10:06:24: EPOCH 5 - PROGRESS: at 40.33% examples, 194079 words/s, in_qsize 5, out_qsize 0
# INFO - 10:06:25: EPOCH 5 - PROGRESS: at 41.98% examples, 194434 words/s, in_qsize 5, out_qsize 0
# INFO - 10:06:26: EPOCH 5 - PROGRESS: at 43.74% examples, 195496 words/s, in_qsize 5, out_qsize 0
# INFO - 10:06:27: EPOCH 5 - PROGRESS: at 45.56% examples, 196565 words/s, in_qsize 4, out_qsize 1
# INFO - 10:06:28: EPOCH 5 - PROGRESS: at 47.38% examples, 197790 words/s, in_qsize 5, out_qsize 0
# INFO - 10:06:29: EPOCH 5 - PROGRESS: at 49.38% examples, 199354 words/s, in_qsize 6, out_qsize 0
# INFO - 10:06:30: EPOCH 5 - PROGRESS: at 51.03% examples, 199620 words/s, in_qsize 6, out_qsize 0
# INFO - 10:06
words/s, in_qsize 5, out_qsize 0
# INFO - 10:07:10: EPOCH 6 - PROGRESS: at 7.47% examples, 187572 words/s, in_qsize 6, out_qsize 1
# INFO - 10:07:11: EPOCH 6 - PROGRESS: at 9.29% examples, 193816 words/s, in_qsize 4, out_qsize 1
# INFO - 10:07:13: EPOCH 6 - PROGRESS: at 10.88% examples, 193292 words/s, in_qsize 6, out_qsize 0
# INFO - 10:07:14: EPOCH 6 - PROGRESS: at 12.76% examples, 198308 words/s, in_qsize 5, out_qsize 2
# INFO - 10:07:15: EPOCH 6 - PROGRESS: at 14.52% examples, 200705 words/s, in_qsize 5, out_qsize 0
# INFO - 10:07:16: EPOCH 6 - PROGRESS: at 16.52% examples, 205630 words/s, in_qsize 5, out_qsize 0
# INFO - 10:07:17: EPOCH 6 - PROGRESS: at 18.34% examples, 207481 words/s, in_qsize 5, out_qsize 0
# INFO - 10:07:18: EPOCH 6 - PROGRESS: at 20.16% examples, 208744 words/s, in_qsize 5, out_qsize 0
# INFO - 10:07:19: EPOCH 6 - PROGRESS: at 21.93% examples, 209495 words/s, in_qsize 6, out_qsize 0
# INFO - 10:07:20: EPOCH 6 - PROGRESS: at 23.34% examples, 207589 words/s, in_qsize 6, out_qsize 0
# INFO - 10:07:21: EPOCH 6 - PROGRESS: at 24.93% examples, 206645 words/s, in_qsize 5, out_qsize 0
# INFO - 10:07:22: EPOCH 6 - PROGRESS: at 26.69% examples, 207935 words/s, in_qsize 5, out_qsize 0
# INFO - 10:07:23: EPOCH 6 - PROGRESS: at 28.63% examples, 209831 words/s, in_qsize 5, out_qsize 0
# INFO - 10:07:24: EPOCH 6 - PROGRESS: at 30.22% examples, 209535 words/s, in_qsize 5, out_qsize 0
# INFO - 10:07:25: EPOCH 6 - PROGRESS: at 31.98% examples, 210335 words/s, in_qsize 6, out_qsize 0
# INFO - 10:07:26: EPOCH 6 - PROGRESS: at 33.92% examples, 211486 words/s, in_qsize 6, out_qsize 0
# INFO - 10:07:27: EPOCH 6 - PROGRESS: at 35.68% examples, 212154 words/s, in_qsize 5, out_qsize 0
# INFO - 10:07:28: EPOCH 6 - PROGRESS: at 37.57% examples, 213353 words/s, in_qsize 5, out_qsize 0
# INFO - 10:07:29: EPOCH 6 - PROGRESS: at 39.15% examples, 212670 words/s, in_qsize 5, out_qsize 0
# INFO - 10:07:30: EPOCH 6 - PROGRESS: at 40.92% examples, 213149 words/s, in_qsize 6, out_qsize 1
# INFO - 10:07:31: EPOCH 6 - PROGRESS: at 42.74% examples, 213368 words/s, in_qsize 6, out_qsize 1
# INFO - 10:07:32: EPOCH 6 - PROGRESS: at 44.74% examples, 214490 words/s, in_qsize 5, out_qsize 0
# INFO - 10:07:33: EPOCH 6 - PROGRESS: at 46.50% examples, 214943 words/s, in_qsize 5, out_qsize 0
# INFO - 10:07:34: EPOCH 6 - PROGRESS: at 48.44% examples, 215606 words/s, in_qsize 6, out_qsize 0
# INFO - 10:07:35: EPOCH 6 - PROGRESS: at 49.74% examples, 213609 words/s, in_qsize 5, out_qsize 0
# INFO - 10:07:36: EPOCH 6 - PROGRESS: at 51.50% examples, 213491 words/s, in_qsize 5, out_qsize 0
# INFO - 10:07:37: EPOCH 6 - PROGRESS: at 53.32% examples, 214160 words/s, in_qsize 5, out_qsize 0
# INFO - 10:07:38: EPOCH 6 - PROGRESS: at 55.03% examples, 213938 words/s, in_qsize 6, out_qsize 1
# INFO - 10:07:39: EPOCH 6 - PROGRESS: at 57.20% examples, 215589 words/s, in_qsize 5, out_qsize 0
# INFO - 10:07:40: EPOCH 6 - PROGRESS: at 58.91% examples, 215688 words/s, in_qsize 5, out_qsize 0
# INFO - 10:07:41: EPOCH 6 - PROGRESS: at 60.67% examples, 216028 words/s, in_qsize 6, out_qsize 0
# INFO - 10:07:42: EPOCH 6 - PROGRESS: at 62.38% examples, 215916 words/s, in_qsize 6, out_qsize 0
# INFO - 10:07:43: EPOCH 6 - PROGRESS: at 64.20% examples, 216386 words/s, in_qsize 6, out_qsize 0
# INFO - 10:07:45: EPOCH 6 - PROGRESS: at 65.90% examples, 216279 words/s, in_qsize 5, out_qsize 0
# INFO - 10:07:46: EPOCH 6 - PROGRESS: at 67.49% examples, 215871 words/s, in_qsize 6, out_qsize 0
# INFO - 10:07:47: EPOCH 6 - PROGRESS: at 68.72% examples, 214335 words/s, in_qsize 5, out_qsize 0
# INFO - 10:07:48: EPOCH 6 - PROGRESS: at 69.66% examples, 211951 words/s, in_qsize 6, out_qsize 0
# INFO - 10:07:49: EPOCH 6 - PROGRESS: at 70.96% examples, 210890 words/s, in_qsize 5, out_qsize 2
# INFO - 10:07:50: EPOCH 6 - PROGRESS: at 72.49% examples, 210275 words/s, in_qsize 6, out_qsize 0
# INFO - 10:07:51: EPOCH 6 - PROGRESS: at 74.43% examples, 210862 words/s, in_qsize 6, out_qsize 2
# INFO - 10:07:52: EPOCH 6 - PROGRESS: at 75.66% examples, 209455 words/s, in_qsize 4, out_qsize 1
# INFO - 10:07:53: EPOCH 6 - PROGRESS: at 76.84% examples, 207830 words/s, in_qsize 5, out_qsize 1
# INFO - 10:07:54: EPOCH 6 - PROGRESS: at 78.13% examples, 206797 words/s, in_qsize 5, out_qsize 0
# INFO - 10:07:55: EPOCH 6 - PROGRESS: at 79.60% examples, 206210 words/s, in_qsize 6, out_qsize 0
# INFO - 10:07:56: EPOCH 6 - PROGRESS: at 80.95% examples, 205382 words/s, in_qsize 4, out_qsize 1
# INFO - 10:07:57: EPOCH 6 - PROGRESS: at 82.48% examples, 204948 words/s, in_qsize 4, out_qsize 1
# INFO - 10:07:58: EPOCH 6 - PROGRESS: at 83.83% examples, 204339 words/s, in_qsize 6, out_qsize 0
# INFO - 10:07:59: EPOCH 6 - PROGRESS: at 85.19% examples, 203724 words/s, in_qsize 6, out_qsize 0
# INFO - 10:08:00: EPOCH 6 - PROGRESS: at 86.77% examples, 203485 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:01: EPOCH 6 - PROGRESS: at 88.18% examples, 203032 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:02: EPOCH 6 - PROGRESS: at 89.83% examples, 203210 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:03: EPOCH 6 - PROGRESS: at 91.77% examples, 203863 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:04: EPOCH 6 - PROGRESS: at 93.42% examples, 203889 words/s, in_qsize 6, out_qsize 0
# INFO - 10:08:05: EPOCH 6 - PROGRESS: at 95.12% examples, 204078 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:06: EPOCH 6 - PROGRESS: at 96.71% examples, 204047 words/s, in_qsize 6, out_qsize 0
# INFO - 10:08:07: EPOCH 6 - PROGRESS: at 98.06% examples, 203389 words/s, in_qsize 6, out_qsize 0
# INFO - 10:08:08: EPOCH 6 - PROGRESS: at 99.12% examples, 202253 words/s, in_qsize 6, out_qsize 0
# INFO - 10:08:09: worker thread finished; awaiting finish of 2 more threads
# INFO - 10:08:09: worker thread finished; awaiting finish of 1 more threads
# INFO - 10:08:09: worker thread finished; awaiting finish of 0 more threads
# INFO - 10:08:09: EPOCH - 6 : training on 17005207 raw words (12819466 effective words) took 63.4s, 202216 effective words/s
# INFO - 10:08:10: EPOCH 7 - PROGRESS: at 1.47% examples, 189289 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:11: EPOCH 7 - PROGRESS: at 2.59% examples, 166191 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:12: EPOCH 7 - PROGRESS: at 4.29% examples, 180526 words/s, in_qsize 6, out_qsize 1
# INFO - 10:08:13: EPOCH 7 - PROGRESS: at 5.88% examples, 185228 words/s, in_qsize 6, out_qsize 0
# INFO - 10:08:14: EPOCH 7 - PROGRESS: at 7.47% examples, 187339 words/s, in_qsize 4, out_qsize 1
# INFO - 10:08:15: EPOCH 7 - PROGRESS: at 8.94% examples, 185220 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:16: EPOCH 7 - PROGRESS: at 10.11% examples, 179561 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:17: EPOCH 7 - PROGRESS: at 11.41% examples, 177111 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:18: EPOCH 7 - PROGRESS: at 13.23% examples, 182302 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:19: EPOCH 7 - PROGRESS: at 15.17% examples, 188665 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:20: EPOCH 7 - PROGRESS: at 17.23% examples, 195008 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:21: EPOCH 7 - PROGRESS: at 19.17% examples, 199140 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:22: EPOCH 7 - PROGRESS: at 20.46% examples, 195102 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:23: EPOCH 7 - PROGRESS: at 21.69% examples, 192585 words/s, in_qsize 6, out_qsize 0
# INFO - 10:08:24: EPOCH 7 - PROGRESS: at 23.05% examples, 191170 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:25: EPOCH 7 - PROGRESS: at 24.51% examples, 190446 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:26: EPOCH 7 - PROGRESS: at 26.04% examples, 190748 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:27: EPOCH 7 - PROGRESS: at 27.57% examples, 190809 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:28: EPOCH 7 - PROGRESS: at 28.87% examples, 189173 words/s, in_qsize 4, out_qsize 1
# INFO - 10:08:29: EPOCH 7 - PROGRESS: at 30.57% examples, 190219 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:30: EPOCH 7 - PROGRESS: at 31.75% examples, 188433 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:31: EPOCH 7 - PROGRESS: at 33.22% examples, 188301 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:32: EPOCH 7 - PROGRESS: at 34.51% examples, 186933 words/s, in_qsize 6, out_qsize 0
# INFO - 10:08:34: EPOCH 7 - PROGRESS: at 35.68% examples, 185052 words/s, in_qsize 6, out_qsize 0
# INFO - 10:08:35: EPOCH 7 - PROGRESS: at 37.45% examples, 186591 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:36: EPOCH 7 - PROGRESS: at 39.09% examples, 187462 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:37: EPOCH 7 - PROGRESS: at 41.03% examples, 189418 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:38: EPOCH 7 - PROGRESS: at 42.74% examples, 190257 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:39: EPOCH 7 - PROGRESS: at 44.15% examples, 189857 words/s, in_qsize 6, out_qsize 0
# INFO - 10:08:40: EPOCH 7 - PROGRESS: at 45.80% examples, 190561 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:41: EPOCH 7 - PROGRESS: at 47.50% examples, 191169 words/s, in_qsize 4, out_qsize 1
# INFO - 10:08:42: EPOCH 7 - PROGRESS: at 49.38% examples, 192685 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:43: EPOCH 7 - PROGRESS: at 51.09% examples, 193452 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:44: EPOCH 7 - PROGRESS: at 53.09% examples, 195283 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:45: EPOCH 7 - PROGRESS: at 54.50% examples, 194745 words/s, in_qsize 4, out_qsize 1
# INFO - 10:08:46: EPOCH 7 - PROGRESS: at 56.44% examples, 196170 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:47: EPOCH 7 - PROGRESS: at 58.38% examples, 197403 words/s, in_qsize 6, out_qsize 0
# INFO - 10:08:48: EPOCH 7 - PROGRESS: at 60.32% examples, 198706 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:49: EPOCH 7 - PROGRESS: at 62.08% examples, 199223 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:50: EPOCH 7 - PROGRESS: at 63.96% examples, 200243 words/s, in_qsize 6, out_qsize 0
# INFO - 10:08:51: EPOCH 7 - PROGRESS: at 64.90% examples, 198033 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:52: EPOCH 7 - PROGRESS: at 66.02% examples, 195851 words/s, in_qsize 6, out_qsize 2
# INFO - 10:08:53: EPOCH 7 - PROGRESS: at 67.20% examples, 194588 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:54: EPOCH 7 - PROGRESS: at 68.55% examples, 193972 words/s, in_qsize 6, out_qsize 2
# INFO - 10:08:55: EPOCH 7 - PROGRESS: at 70.25% examples, 194488 words/s, in_qsize 4, out_qsize 1
# INFO - 10:08:56: EPOCH 7 - PROGRESS: at 72.13% examples, 195197 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:57: EPOCH 7 - PROGRESS: at 73.60% examples, 194845 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:58: EPOCH 7 - PROGRESS: at 74.90% examples, 194156 words/s, in_qsize 5, out_qsize 0
# INFO - 10:08:59: EPOCH 7 - PROGRESS: at 76.19% examples, 193250 words/s, in_qsize 6, out_qsize 0
# INFO - 10:09:00: EPOCH 7 - PROGRESS: at 77.72% examples, 193048 words/s, in_qsize 6, out_qsize 0
# INFO - 10:09:01: EPOCH 7 - PROGRESS: at 79.01% examples, 192455 words/s, in_qsize 6, out_qsize 0
# INFO - 10:09:02: EPOCH 7 - PROGRESS: at 80.07% examples, 191349 words/s, in_qsize 5, out_qsize 0
# INFO - 10:09:03: EPOCH 7 - PROGRESS: at 81.31% examples, 190707 words/s, in_qsize 5, out_qsize 0
# INFO - 10:09:04: EPOCH 7 - PROGRESS: at 82.83% examples, 190727 words/s, in_qsize 5, out_qsize 0
# INFO - 10:09:05: EPOCH 7 - PROGRESS: at 84.30% examples, 190687 words/s, in_qsize 5, out_qsize 0
# INFO - 10:09:06: EPOCH 7 - PROGRESS: at 86.18% examples, 191495 words/s, in_qsize 5, out_qsize 0
# INFO - 10:09:08: EPOCH 7 - PROGRESS: at 87.83% examples, 191697 words/s, in_qsize 5, out_qsize 0
# INFO - 10:09:09: EPOCH 7 - PROGRESS: at 89.01% examples, 190888 words/s, in_qsize 5, out_qsize 0
# INFO - 10:09:10: EPOCH 7 - PROGRESS: at 90.30% examples, 190431 words/s, in_qsize 5, out_qsize 0
# INFO - 10:09:11: EPOCH 7 - PROGRESS: at 91.77% examples, 190298 words/s, in_qsize 6, out_qsize 0
# INFO - 10:09:12: EPOCH 7 - PROGRESS: at 93.47% examples, 190688 words/s, in_qsize 5, out_qsize 0
# INFO - 10:09:13: EPOCH 7 - PROGRESS: at 95.12% examples, 190946 words/s, in_qsize 5, out_qsize 0
# INFO - 10:09:14: EPOCH 7 - PROGRESS: at 96.71% examples, 191121 words/s, in_qsize 5, out_qsize 0
# INFO - 10:09:15: EPOCH 7 - PROGRESS: at 98.24% examples, 191103 words/s, in_qsize 5, out_qsize 0
# INFO - 10:09:16: worker thread finished; awaiting finish of 2 more threads
# INFO - 10:09:16: worker thread finished; awaiting finish of 1 more threads
# INFO - 10:09:16: worker thread finished; awaiting finish of 0 more threads
# INFO - 10:09:16: EPOCH - 7 : training on 17005207 raw words (12817032 effective words) took 66.8s, 191882 effective words/s
# INFO - 10:09:17: EPOCH 8 - PROGRESS: at 1.76% examples, 218857 words/s, in_qsize 6, out_qsize 0
# INFO - 10:09:18: EPOCH 8 - PROGRESS: at 3.12% examples, 193034 words/s, in_qsize 5, out_qsize 0
# INFO - 10:09:19: EPOCH 8 - PROGRESS: at 4.59% examples, 188254 words/s, in_qsize 6, out_qsize 0
# INFO - 10:09:20: EPOCH 8 - PROGRESS: at 5.76% examples, 175071 words/s, in_qsize 6, out_qsize 0
# INFO - 10:09:21: EPOCH 8 - PROGRESS: at 7.00% examples, 170978 words/s, in_qsize 5, out_qsize 0
# INFO - 10:09:22: EPOCH 8 - PROGRESS: at 8.41% examples, 172258 words/s, in_qsize 5, out_qsize 1
# INFO - 10:09:23: EPOCH 8 - PROGRESS: at 10.23% examples, 179404 words/s, in_qsize 5, out_qsize 0
# INFO - 10:09:24: EPOCH 8 - PROGRESS: at 11.58% examples, 178128 words/s, in_qsize 5, out_qsize 0
# INFO - 10:09:25: EPOCH 8 - PROGRESS: at 12.93% examples, 177562 words/s, in_qsize 5, out_qsize 0
# INFO - 10:09:26: EPOCH 8 - PROGRESS: at 14.52% examples, 179815 words/s, in_qsize 4, out_qsize 0
# INFO - 10:09:27: EPOCH 8 - PROGRESS: at 15.99% examples, 180010 words/s, in_qsize 4, out_qsize 1
# INFO - 10:09:28: EPOCH 8 - PROGRESS: at 17.40% examples, 179110 words/s, in_qsize 4, out_qsize 1
# INFO - 10:09:29: EPOCH 8 - PROGRESS: at 19.46% examples, 185267 words/s, in_qsize 5, out_qsize 0
# INFO - 10:09:30: EPOCH 8 - PROGRESS: at 21.22% examples, 187569 words/s, in_qsize 4, out_qsize 1
# INFO - 10:09:31: EPOCH 8 - PROGRESS: at 23.16% examples, 191328 words/s, in_qsize 5, out_qsize 0
# INFO - 10:09:32: EPOCH 8 - PROGRESS: at 24.63% examples, 190708 words/s, in_qsize 6, out_qsize 0
# INFO - 10:09:33: EPOCH 8 - PROGRESS: at 25.87% examples, 188677 words/s, in_qsize 5, out_qsize 0
# INFO - 10:09:34: EPOCH 8 - PROGRESS: at 27.22% examples, 187382 words/s, in_qsize 5, out_qsize 0
# ...
# INFO - 10:35:45: EPOCH 37 - PROGRESS: at 92.06% examples, 274815 words/s, in_qsize 5, out_qsize 0
# INFO - 10:35:46: EPOCH 37 - PROGRESS: at 94.42% examples, 275258 words/s, in_qsize 5, out_qsize 0
# INFO - 10:35:47: EPOCH 37 - PROGRESS: at 96.36% examples, 274638 words/s, in_qsize 5, out_qsize 0
# INFO - 10:35:48: EPOCH 37 - PROGRESS: at 98.41% examples, 274114 words/s, in_qsize 5, out_qsize 0
# INFO - 10:35:49: worker thread finished; awaiting finish of 2 more threads
# INFO - 10:35:49: worker thread finished; awaiting finish of 1 more threads
# INFO - 10:35:49: worker thread finished; awaiting finish of 0 more threads
# INFO - 10:35:49: EPOCH - 37 : training on 17005207 raw words (12820774 effective words) took 46.8s, 273842 effective words/s
# INFO - 10:35:50: EPOCH 38 - PROGRESS: at 1.94% examples, 244730 words/s, in_qsize 5, out_qsize 0
# INFO - 10:35:51: EPOCH 38 - PROGRESS: at 4.17% examples, 263612 words/s, in_qsize 5, out_qsize 0
# INFO - 10:35:52: EPOCH 38 - PROGRESS: at 6.35% examples, 266016 words/s, in_qsize 5, out_qsize 0
# INFO - 10:35:53: EPOCH 38 - PROGRESS: at 8.64% examples, 268832 words/s, in_qsize 5, out_qsize 0
# INFO - 10:35:54: EPOCH 38 - PROGRESS: at 10.46% examples, 260859 words/s, in_qsize 5, out_qsize 0
# INFO - 10:35:55: EPOCH 38 - PROGRESS: at 12.40% examples, 257516 words/s, in_qsize 4, out_qsize 1
# INFO - 10:35:56: EPOCH 38 - PROGRESS: at 14.58% examples, 258629 words/s, in_qsize 6, out_qsize 1
# INFO - 10:35:57: EPOCH 38 - PROGRESS: at 16.81% examples, 261703 words/s, in_qsize 5, out_qsize 0
# INFO - 10:35
words/s, in_qsize 5, out_qsize 0
# INFO - 10:36:41: EPOCH 39 - PROGRESS: at 4.23% examples, 269383 words/s, in_qsize 5, out_qsize 0
# INFO - 10:36:42: EPOCH 39 - PROGRESS: at 6.53% examples, 274895 words/s, in_qsize 3, out_qsize 2
# INFO - 10:36:43: EPOCH 39 - PROGRESS: at 8.88% examples, 280399 words/s, in_qsize 5, out_qsize 0
# INFO - 10:36:44: EPOCH 39 - PROGRESS: at 10.58% examples, 267946 words/s, in_qsize 5, out_qsize 0
# INFO - 10:36:45: EPOCH 39 - PROGRESS: at 12.76% examples, 267882 words/s, in_qsize 4, out_qsize 1
# INFO - 10:36:46: EPOCH 39 - PROGRESS: at 15.11% examples, 271805 words/s, in_qsize 6, out_qsize 1
# INFO - 10:36:47: EPOCH 39 - PROGRESS: at 17.11% examples, 268860 words/s, in_qsize 4, out_qsize 1
# INFO - 10:36:48: EPOCH 39 - PROGRESS: at 19.46% examples, 272337 words/s, in_qsize 5, out_qsize 0
# INFO - 10:36:49: EPOCH 39 - PROGRESS: at 21.28% examples, 268108 words/s, in_qsize 6, out_qsize 0
# INFO - 10:36:50: EPOCH 39 - PROGRESS: at 23.10% examples, 265008 words/s, in_qsize 5, out_qsize 1
# INFO - 10:36:51: EPOCH 39 - PROGRESS: at 25.22% examples, 264217 words/s, in_qsize 5, out_qsize 0
# INFO - 10:36:52: EPOCH 39 - PROGRESS: at 27.45% examples, 265517 words/s, in_qsize 5, out_qsize 0
# INFO - 10:36:53: EPOCH 39 - PROGRESS: at 29.63% examples, 266772 words/s, in_qsize 5, out_qsize 0
# INFO - 10:36:54: EPOCH 39 - PROGRESS: at 31.45% examples, 264727 words/s, in_qsize 5, out_qsize 0
# INFO - 10:36:55: EPOCH 39 - PROGRESS: at 33.39% examples, 263639 words/s, in_qsize 5, out_qsize 0
# INFO - 10:36:56: EPOCH 39 - PROGRESS: at 35.63% examples, 264436 words/s, in_qsize 4, out_qsize 1
# INFO - 10:36:57: EPOCH 39 - PROGRESS: at 37.80% examples, 264735 words/s, in_qsize 5, out_qsize 0
# INFO - 10:36:58: EPOCH 39 - PROGRESS: at 39.98% examples, 265267 words/s, in_qsize 5, out_qsize 0
# INFO - 10:36:59: EPOCH 39 - PROGRESS: at 41.92% examples, 264417 words/s, in_qsize 6, out_qsize 0
# INFO - 10:37:00: EPOCH 39 - PROGRESS: at 43.56% examples, 261663 words/s, in_qsize 6, out_qsize 0
# INFO - 10:37:01: EPOCH 39 - PROGRESS: at 45.80% examples, 262814 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:02: EPOCH 39 - PROGRESS: at 47.80% examples, 262618 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:03: EPOCH 39 - PROGRESS: at 49.97% examples, 263387 words/s, in_qsize 6, out_qsize 0
# INFO - 10:37:04: EPOCH 39 - PROGRESS: at 52.15% examples, 263874 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:05: EPOCH 39 - PROGRESS: at 54.32% examples, 264259 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:06: EPOCH 39 - PROGRESS: at 56.38% examples, 263985 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:07: EPOCH 39 - PROGRESS: at 58.38% examples, 263169 words/s, in_qsize 5, out_qsize 2
# INFO - 10:37:08: EPOCH 39 - PROGRESS: at 60.49% examples, 263098 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:09: EPOCH 39 - PROGRESS: at 62.61% examples, 263220 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:10: EPOCH 39 - PROGRESS: at 64.61% examples, 262438 words/s, in_qsize 6, out_qsize 1
# INFO - 10:37:11: EPOCH 39 - PROGRESS: at 66.49% examples, 261739 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:12: EPOCH 39 - PROGRESS: at 68.67% examples, 262109 words/s, in_qsize 4, out_qsize 1
# INFO - 10:37:13: EPOCH 39 - PROGRESS: at 70.72% examples, 261916 words/s, in_qsize 6, out_qsize 0
# INFO - 10:37:14: EPOCH 39 - PROGRESS: at 72.90% examples, 262264 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:15: EPOCH 39 - PROGRESS: at 75.19% examples, 262836 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:16: EPOCH 39 - PROGRESS: at 77.07% examples, 262003 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:17: EPOCH 39 - PROGRESS: at 79.07% examples, 261503 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:18: EPOCH 39 - PROGRESS: at 81.31% examples, 261789 words/s, in_qsize 6, out_qsize 0
# INFO - 10:37:19: EPOCH 39 - PROGRESS: at 83.48% examples, 262209 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:20: EPOCH 39 - PROGRESS: at 85.66% examples, 262423 words/s, in_qsize 6, out_qsize 0
# INFO - 10:37:21: EPOCH 39 - PROGRESS: at 87.42% examples, 261520 words/s, in_qsize 6, out_qsize 0
# INFO - 10:37:22: EPOCH 39 - PROGRESS: at 89.07% examples, 260301 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:24: EPOCH 39 - PROGRESS: at 91.06% examples, 259973 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:25: EPOCH 39 - PROGRESS: at 93.30% examples, 260344 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:26: EPOCH 39 - PROGRESS: at 95.47% examples, 260619 words/s, in_qsize 3, out_qsize 1
# INFO - 10:37:27: EPOCH 39 - PROGRESS: at 97.59% examples, 260522 words/s, in_qsize 6, out_qsize 0
# INFO - 10:37:28: EPOCH 39 - PROGRESS: at 99.35% examples, 259739 words/s, in_qsize 6, out_qsize 2
# INFO - 10:37:28: worker thread finished; awaiting finish of 2 more threads
# INFO - 10:37:28: worker thread finished; awaiting finish of 1 more threads
# INFO - 10:37:28: worker thread finished; awaiting finish of 0 more threads
# INFO - 10:37:28: EPOCH - 39 : training on 17005207 raw words (12821121 effective words) took 49.3s, 260035 effective words/s
# INFO - 10:37:29: EPOCH 40 - PROGRESS: at 2.12% examples, 268692 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:30: EPOCH 40 - PROGRESS: at 4.35% examples, 273463 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:31: EPOCH 40 - PROGRESS: at 6.58% examples, 274348 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:32: EPOCH 40 - PROGRESS: at 8.64% examples, 267598 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:33: EPOCH 40 - PROGRESS: at 10.58% examples, 263634 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:34: EPOCH 40 - PROGRESS: at 12.35% examples, 255744 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:35: EPOCH 40 - PROGRESS: at 14.76% examples, 262105 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:36: EPOCH 40 - PROGRESS: at 17.05% examples, 265148 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:37: EPOCH 40 - PROGRESS: at 19.17% examples, 265440 words/s, in_qsize 6, out_qsize 0
# INFO - 10:37:38: EPOCH 40 - PROGRESS: at 21.34% examples, 266302 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:39: EPOCH 40 - PROGRESS: at 23.05% examples, 261475 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:40: EPOCH 40 - PROGRESS: at 25.34% examples, 263591 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:41: EPOCH 40 - PROGRESS: at 27.40% examples, 263727 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:42: EPOCH 40 - PROGRESS: at 29.51% examples, 264433 words/s, in_qsize 6, out_qsize 0
# INFO - 10:37:43: EPOCH 40 - PROGRESS: at 31.63% examples, 264884 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:44: EPOCH 40 - PROGRESS: at 33.39% examples, 262267 words/s, in_qsize 6, out_qsize 0
# INFO - 10:37:45: EPOCH 40 - PROGRESS: at 35.80% examples, 264837 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:46: EPOCH 40 - PROGRESS: at 38.04% examples, 265860 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:47: EPOCH 40 - PROGRESS: at 40.27% examples, 266808 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:48: EPOCH 40 - PROGRESS: at 42.27% examples, 266128 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:49: EPOCH 40 - PROGRESS: at 44.21% examples, 265051 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:50: EPOCH 40 - PROGRESS: at 46.15% examples, 264308 words/s, in_qsize 6, out_qsize 1
# INFO - 10:37:51: EPOCH 40 - PROGRESS: at 48.27% examples, 264539 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:52: EPOCH 40 - PROGRESS: at 50.26% examples, 264224 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:53: EPOCH 40 - PROGRESS: at 52.32% examples, 264023 words/s, in_qsize 6, out_qsize 0
# INFO - 10:37:54: EPOCH 40 - PROGRESS: at 54.38% examples, 263998 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:55: EPOCH 40 - PROGRESS: at 56.26% examples, 262894 words/s, in_qsize 6, out_qsize 2
# INFO - 10:37:56: EPOCH 40 - PROGRESS: at 58.50% examples, 263347 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:57: EPOCH 40 - PROGRESS: at 60.55% examples, 263449 words/s, in_qsize 6, out_qsize 0
# INFO - 10:37:58: EPOCH 40 - PROGRESS: at 62.73% examples, 263874 words/s, in_qsize 5, out_qsize 0
# INFO - 10:37:59: EPOCH 40 - PROGRESS: at 64.96% examples, 264523 words/s, in_qsize 5, out_qsize 1
# INFO - 10:38:00: EPOCH 40 - PROGRESS: at 66.90% examples, 263859 words/s, in_qsize 5, out_qsize 0
# INFO - 10:38:01: EPOCH 40 - PROGRESS: at 69.08% examples, 264226 words/s, in_qsize 5, out_qsize 0
# INFO - 10:38:03: EPOCH 40 - PROGRESS: at 71.19% examples, 264368 words/s, in_qsize 5, out_qsize 0
# INFO - 10:38:04: EPOCH 40 - PROGRESS: at 73.43% examples, 264617 words/s, in_qsize 6, out_qsize 0
# INFO - 10:38:05: EPOCH 40 - PROGRESS: at 75.96% examples, 265930 words/s, in_qsize 5, out_qsize 0
# INFO - 10:38:06: EPOCH 40 - PROGRESS: at 78.07% examples, 265845 words/s, in_qsize 6, out_qsize 0
# INFO - 10:38:07: EPOCH 40 - PROGRESS: at 79.89% examples, 264739 words/s, in_qsize 6, out_qsize 0
# INFO - 10:38:08: EPOCH 40 - PROGRESS: at 82.01% examples, 264841 words/s, in_qsize 4, out_qsize 1
# INFO - 10:38:09: EPOCH 40 - PROGRESS: at 84.13% examples, 264924 words/s, in_qsize 4, out_qsize 1
# INFO - 10:38:10: EPOCH 40 - PROGRESS: at 86.13% examples, 264413 words/s, in_qsize 5, out_qsize 0
# INFO - 10:38:11: EPOCH 40 - PROGRESS: at 88.36% examples, 264517 words/s, in_qsize 4, out_qsize 1
# INFO - 10:38:12: EPOCH 40 - PROGRESS: at 90.18% examples, 263827 words/s, in_qsize 5, out_qsize 0
# INFO - 10:38:13: EPOCH 40 - PROGRESS: at 92.24% examples, 263413 words/s, in_qsize 4, out_qsize 1
# INFO - 10:38:14: EPOCH 40 - PROGRESS: at 94.42% examples, 263639 words/s, in_qsize 6, out_qsize 0
# INFO - 10:38:15: EPOCH 40 - PROGRESS: at 96.59% examples, 263807 words/s, in_qsize 5, out_qsize 0
# INFO - 10:38:16: EPOCH 40 - PROGRESS: at 98.77% examples, 264010 words/s, in_qsize 6, out_qsize 1
# INFO - 10:38:16: worker thread finished; awaiting finish of 2 more threads
# INFO - 10:38:16: worker thread finished; awaiting finish of 1 more threads
# INFO - 10:38:16: worker thread finished; awaiting finish of 0 more threads
# INFO - 10:38:16: EPOCH - 40 : training on 17005207 raw words (12821533 effective words) took 48.5s, 264150 effective words/s
# INFO - 10:38:16: training on a 680208280 raw words (512833562 effective words) took 2199.4s, 233173 effective words/s

# %%
#Get document vector
print(model.infer_vector('gensim is really awesome'.split(' ')))
# Out:
# [ 0.18035454  0.41629905  0.25469506 -0.22324803 -0.09268823 -0.05151142
#  -0.08480603 -0.00570442  0.08062097  0.00310741  0.17478175 -0.00154936
#  -0.09330877 -0.02339078  0.0199794   0.04549846 -0.04683316 -0.03828195
#  -0.3936776  -0.2056224  -0.04153012 -0.2085073   0.3692062   0.12547413
#  -0.03771724  0.09459786  0.34567693 -0.34003636 -0.14349678  0.0229786
#   0.1584827   0.02953391  0.13116093  0.02679738  0.02890064  0.06687283
#   0.2509888   0.15626836 -0.03766628  0.24216698  0.04326655  0.18548243
#   0.25629497 -0.10298692 -0.3509259  -0.06340942 -0.22913803 -0.14003526
#   0.04637286 -0.14653628]

# %% [markdown]
# Used materials:
#
# - https://www.machinelearningplus.com/nlp/gensim-tutorial/
# - https://radimrehurek.com/gensim/models/word2vec.html
# - https://radimrehurek.com/gensim/models/keyedvectors.html
# - https://rare-technologies.com/word2vec-tutorial/
